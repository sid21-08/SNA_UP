# %%
# !pip install pycombo
# Out:
# Requirement already satisfied: pycombo in /usr/local/lib/python3.7/dist-packages (0.1.7)
# Requirement already satisfied: importlib-metadata<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from pycombo) (1.7.0)
# Requirement already satisfied: pybind11<3.0.0,>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pycombo) (2.9.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata<2.0,>=1.0->pycombo) (3.8.0)

# %%
import datetime
import calendar
import collections
from operator import itemgetter

import numpy as np
import pandas as pd

# Networks 
import networkx as nx
# Community Detection
import community as community_louvain 
import pycombo 

# Visualization
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
import seaborn as sns

# Interactive Maps/Visaualization
import folium
from folium import plugins
import plotly.graph_objects as go

# %%
# !pip install igraph
# Out:
# Requirement already satisfied: igraph in /usr/local/lib/python3.7/dist-packages (0.9.10)
# Requirement already satisfied: texttable>=1.6.2 in /usr/local/lib/python3.7/dist-packages (from igraph) (1.6.4)

# %%
from igraph import *
import igraph

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
dataframe=pd.read_csv('/content/drive/MyDrive/SNA/database.csv')
dataframe.tail()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (2,4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                     departure               return departure_id  \
# 12157453  2017-10-30 23:43:00  2017-10-30 23:55:00         64.0
# 12157454  2017-10-30 23:49:00  2017-10-31 04:49:00        117.0
# 12157455  2017-10-30 23:52:00  2017-10-31 00:02:00        142.0
# 12157456  2017-10-30 23:57:00  2017-10-31 00:00:00         28.0
# 12157457  2017-10-30 23:59:00  2017-10-31 00:12:00         20.0
#
#              departure_name return_id      return_name  distance (m)  \
# 12157453    Tyynenmerenkatu      64.0  Tyynenmerenkatu         918.0
# 12157454   Brahen puistikko      44.0    Sörnäinen (M)         822.0
# 12157455        Koskelantie     141.0       Intiankatu        1817.0
# 12157456        Lastenlehto      26.0       Kamppi (M)         416.0
# 12157457  Kaisaniemenpuisto     114.0     Ratapihantie        2856.0
#
#           duration (sec.)  avg_speed (km/h)  departure_latitude  \
# 12157453            714.0          0.077143           60.156838
# 12157454            252.0          0.195714           60.189671
# 12157455            594.0          0.183535           60.208749
# 12157456            152.0          0.164211           60.165812
# 12157457            771.0          0.222257           60.173199
#
#           departure_longitude  return_latitude  return_longitude  \
# 12157453            24.920661        60.156838         24.920661
# 12157454            24.948102        60.187736         24.960980
# 12157455            24.946514        60.207858         24.967638
# 12157456            24.927021        60.168610         24.930537
# 12157457            24.943301        60.196431         24.936256
#
#           Air temperature (degC)
# 12157453                     0.4
# 12157454                     0.4
# 12157455                     0.4
# 12157456                     0.4
# 12157457                     0.4

# %%
dataframe.columns
# Out:
# Index(['departure', 'return', 'departure_id', 'departure_name', 'return_id',
#        'return_name', 'distance (m)', 'duration (sec.)', 'avg_speed (km/h)',
#        'departure_latitude', 'departure_longitude', 'return_latitude',
#        'return_longitude', 'Air temperature (degC)'],
#       dtype='object')

# %%
def bikeNetwork(dataframe):
    df = dataframe.copy()
    df.dropna(inplace=True)
    G = nx.Graph()
    G = nx.from_pandas_edgelist(df, 'departure_name', 'return_name', edge_attr=['duration (sec.)','distance (m)'])

    

    # Positions
    stations  = pd.read_csv("https://raw.githubusercontent.com/Geometrein/helsinki-city-bikes/main/data/downloaded_data/station_coordinates.csv")
    stations.set_index('name',inplace=True)
    stations["pos"] = list(zip(stations["longitude"].astype(float), stations["latitude"].astype(float)))
    pos = stations.to_dict()['pos']

    # Map "pos" atribute to nodes from pos dict
    for node, position in pos.items():
        try:
            G.nodes[node]['pos'] = position
        except KeyError:
            pass

    # Draw
    nx.draw_networkx_nodes(G=G,pos=G.nodes.data('pos'), node_color='blue', alpha=0.5)
    nx.draw_networkx_edges(G=G,pos=G.nodes.data('pos'), edge_color='grey', style ="dotted", alpha=0.1, arrows=False)
    
    return G

G = bikeNetwork(dataframe)

# %%
nx.info(G)
# Out:
# 'Graph with 347 nodes and 36462 edges'

# %%
G.degree()
# Out:
# DegreeView({'Kuusitie': 281, 'Esterinportti': 279, 'Kamppi (M)': 302, 'Kasarmitori': 215, 'Porolahden koulu': 155, 'Agnetankuja': 162, 'Vallipolku': 139, 'Korppaanmäentie': 257, 'Länsisatamankatu': 273, 'Vilhonvuorenkatu': 257, 'Radiokatu': 248, 'Porthania': 267, 'Tyynenmerenkatu': 233, 'Hietalahdentori': 278, 'Itämerentori': 314, 'Meilahden sairaala': 277, 'Koskelantie': 264, 'Kalasatama (M)': 268, 'Rautatieläisenkatu': 277, 'A.I. Virtasen aukio': 218, 'Töölönkatu': 260, 'Rautatientori / itä': 288, 'Roihupelto': 138, 'Siilitie (M)': 166, 'Hakaniemi (M)': 268, 'Rajasaarentie': 260, 'Näkinsilta': 261, 'Kiasma': 271, 'Senaatintori': 242, 'Rautatientori / länsi': 295, 'Olympiastadion': 274, 'Tilkanvierto': 290, 'Stenbäckinkatu': 267, 'Pohjankulma': 203, 'Kalevalantie': 202, 'Tulisuontie': 132, 'Herttoniemi (M)': 212, 'Päijänteentie': 245, 'Kauppakorkeakoulu': 247, 'Nordenskiöldinaukio': 277, 'Brahen puistikko': 259, 'Vanha Viertotie': 245, 'Elimäenkatu': 268, 'Ympyrätalo': 296, 'Jätkäsaarenlaituri': 275, 'Kanavaranta': 269, 'Kaivopuisto': 259, 'Säterinniitty': 167, 'Laajalahden aukio': 305, 'Perämiehenkatu': 248, 'Salmisaarenranta': 233, 'Kapteeninpuistikko': 247, 'Arabian kauppakeskus': 263, 'Brahen kenttä': 272, 'Majurinkulma': 210, 'Viiskulma': 249, 'Varsapuistikko': 261, 'Kansallismuseo': 239, 'Haukilahdenkatu': 328, 'Eläinmuseo': 230, 'Baana': 289, 'Paavalinpuisto': 249, 'Narinkka': 293, 'Eteläinen Hesperiankatu': 283, 'Paciuksenkaari': 297, 'Marian sairaala': 281, 'Töölönlahdenkatu': 300, 'Laivalahden puistotie': 183, 'Kesäkatu': 274, 'Korjaamo': 291, 'Fleminginkatu': 284, 'Jäähalli': 260, 'Mastokatu': 194, 'Töölönlahden puisto': 258, 'Heikkilänaukio': 245, 'Gyldenintie': 259, 'Kiskontie': 256, 'Käpyläntie': 245, 'Siltavoudintie': 188, 'Ooppera': 279, 'Linnanmäki': 276, 'Petter Wetterin tie': 210, 'Jalavatie': 265, 'Kriikunakuja': 257, 'Piispankallio': 135, 'Niittykumpu (M)': 200, 'Mannerheimintie': 263, 'Unioninkatu': 267, 'Eteläesplanadi': 271, 'Teollisuuskatu': 261, 'Säterinrinne': 155, 'Liisanpuistikko': 251, 'Verkatehtaanpuisto': 249, 'Munkkiniemen aukio': 291, 'Leppävaaran urheilupuisto': 140, 'Muurarinkuja': 150, 'Heikkiläntie': 238, 'Käpylän asema': 242, 'Kaisaniemenpuisto': 296, 'Annankatu': 247, 'Kulosaari (M)': 226, 'Abraham Wetterin tie': 172, 'Melkonkuja': 205, 'Mamsellimyllynkatu': 112, 'Itäkeskus (M)': 160, 'Velodrominrinne': 249, 'Huopalahdentie': 296, 'Metsänneidonpolku': 200, 'Designmuseo': 219, 'Toppelundinportti': 149, 'Arabiankatu': 257, 'Voikukantie': 130, 'Katariina Saksilaisen katu': 223, 'Laivasillankatu': 214, 'Puotilan ostoskeskus': 106, 'Gunillantie': 111, 'Kalevankatu': 257, 'Ruskeasuon varikko': 241, 'Vanha kirkkopuisto': 284, 'Lintulahdenkatu': 253, 'Viikin tiedepuisto': 215, 'Viikin normaalikoulu': 185, 'Tilkantori': 267, 'Paciuksenkatu': 279, 'Kirkkoherrantie': 170, 'Koskelan varikko': 198, 'Marjaniementie': 111, 'Herttoniemenranta': 191, 'Kustaankatu': 262, 'Hernesaarenranta': 232, 'Intiankatu': 248, 'Töölöntori': 268, 'Pohjolanaukio': 235, 'Merisotilaantori': 194, 'Myllypuro (M)': 136, 'Lastenlehto': 270, 'Mustikkamaa': 211, 'Hollolantie': 250, 'Sörnäinen (M)': 287, 'Piispanportti': 134, 'Lystimäensilta': 105, 'Ritarikatu': 231, 'Kuikkarinne': 241, 'Sepänkatu': 263, 'Takomotie': 241, 'Sepetlahdentie': 100, 'Suomenlahdentie': 176, 'Kuunkatu': 145, 'Pitäjänmäen asema': 210, 'Ahertajantie': 187, 'Hakalehto': 190, 'Keilaniemi (M)': 261, 'Hertanmäenkatu': 274, 'Matinkyläntie': 115, 'Keilalahti': 256, 'Pihlajamäki': 172, 'Isoisänsilta': 255, 'Aulangontie': 171, 'Länsituuli': 208, 'Eerikinkatu': 229, 'Westendinasema': 214, 'Albertinkatu': 248, 'Venttiilikuja': 269, 'Vanha Kauppahalli': 211, 'Lepolantie': 216, 'Puotila (M)': 112, 'Sammonpuistikko': 254, 'Töölöntulli': 291, 'Cygnaeuksenkatu': 228, 'Jämeräntaival': 271, 'Hietaniemenkatu': 253, 'Piispansilta': 207, 'Tiistiläntie': 95, 'Muusantori': 248, 'Ulvilantie': 260, 'Margareetankuja': 145, 'Urheilupuisto (M)': 210, 'Orpaanporras': 105, 'Ehrenst ...

# %%
x=sorted([d for n, d in G.degree()],reverse=True)
for d in x[:5]:
        print(d)
# Out:
# 328
# 314
# 305
# 302
# 300

# %%
y=sorted(G.degree(),key=lambda y: y[1],reverse=True)
for d in y[:5]:
        print(d)
# Out:
# ('Haukilahdenkatu', 328)
# ('Itämerentori', 314)
# ('Laajalahden aukio', 305)
# ('Kamppi (M)', 302)
# ('Töölönlahdenkatu', 300)

# %%
degreeCount = collections.Counter(x)
deg, cnt = zip(*degreeCount.items())
x=sum(deg)/len(deg)

# %%
degreeCount
# Out:
# Counter({73: 1,
#          76: 1,
#          77: 1,
#          85: 1,
#          88: 1,
#          90: 1,
#          95: 1,
#          98: 1,
#          99: 1,
#          100: 1,
#          101: 1,
#          103: 1,
#          105: 2,
#          106: 1,
#          108: 4,
#          110: 1,
#          111: 2,
#          112: 2,
#          113: 1,
#          115: 2,
#          116: 1,
#          117: 1,
#          119: 1,
#          120: 1,
#          121: 1,
#          123: 1,
#          124: 2,
#          125: 1,
#          126: 3,
#          127: 1,
#          128: 2,
#          130: 4,
#          132: 2,
#          134: 2,
#          135: 1,
#          136: 3,
#          138: 1,
#          139: 1,
#          140: 3,
#          141: 2,
#          142: 1,
#          144: 3,
#          145: 4,
#          146: 1,
#          149: 2,
#          150: 2,
#          151: 1,
#          154: 1,
#          155: 3,
#          158: 2,
#          160: 1,
#          161: 1,
#          162: 1,
#          163: 1,
#          164: 1,
#          165: 1,
#          166: 2,
#          167: 2,
#          168: 1,
#          170: 1,
#          171: 4,
#          172: 3,
#          173: 1,
#          175: 1,
#          176: 1,
#          177: 2,
#          179: 1,
#          180: 1,
#          181: 1,
#          182: 2,
#          183: 1,
#          184: 2,
#          185: 4,
#          186: 1,
#          187: 1,
#          188: 3,
#          189: 1,
#          190: 1,
#          191: 3,
#          192: 1,
#          194: 2,
#          196: 1,
#          198: 1,
#          200: 3,
#          202: 1,
#          203: 2,
#          204: 1,
#          205: 2,
#          206: 1,
#          207: 2,
#          208: 1,
#          209: 5,
#          210: 5,
#          211: 3,
#          212: 2,
#          214: 3,
#          215: 3,
#          216: 5,
#          217: 1,
#          218: 4,
#          219: 1,
#          220: 3,
#          221: 1,
#          222: 3,
#          223: 1,
#          226: 3,
#          227: 3,
#          228: 1,
#          229: 1,
#          230: 2,
#          231: 1,
#          232: 2,
#          233: 4,
#          234: 1,
#          235: 1,
#          238: 2,
#          239: 2,
#          241: 3,
#          242: 4,
#          244: 1,
#          245: 4,
#          247: 5,
#          248: 5,
#          249: 5,
#          250: 1,
#          251: 3,
#          253: 3,
#          254: 2,
#          255: 1,
#          256: 2,
#          257: 6,
#          258: 2,
#          259: 4,
#          260: 5,
#          261: 5,
#          262: 2,
#          263: 3,
#          264: 1,
#          265: 1,
#          266: 3,
#          267: 5,
#          268: 5,
#          269: 2,
#          270: 2,
#          271: 3,
#          272: 3,
#          273: 3,
#          274: 4,
#          275: 2,
#          276: 1,
#          277: 5,
#          278: 1,
#          279: 3,
#          280: 1,
#          281: 2,
#          282: 1,
#          283: 1,
#          284: 5,
#          286: 1,
#          287: 1,
#          288: 1,
#          289: 1,
#          290: 1,
#          291: 3,
#          293: 1,
#          295: 1,
#          296: 3,
#          297: 1,
#          300: 1,
#          302: 1,
#          305: 1,
#          314: 1,
#          328: 1})

# %%
x
# Out:
# 200.10982658959537

# %% [markdown]
# Average degree of a node in the graph is approximately 200

# %%
fig,ax=plt.subplots(figsize=(15,7))
plt.bar(deg, cnt, width=1, color='blue')
# Out:
# <BarContainer object of 173 artists>

# %% [markdown]
# Conclusion:
# Haukilahdenkatu has the highest no of degrees(degree centrality) equal to 200. It implies that people make trips to and from Haukilahdenkatu on a regular basis. This means Haukilahdenkatu station is nearer to an important point of interest.
# As we have already found out avg degree of a node in the graph is approximately 200. This means a bike station on an average is connected to 200 nodes.

# %% [markdown]
# Betweenness Centrality

# %%
betweenness_dict = nx.betweenness_centrality(G)

# %%
sorted_betweenness = sorted(betweenness_dict.items(), key=itemgetter(1), reverse=True)
sorted_betweenness
# Out:
# [('Haukilahdenkatu', 0.00713446536080233),
#  ('Itämerentori', 0.00489579608404948),
#  ('Kamppi (M)', 0.0037203436342368394),
#  ('Narinkka', 0.0037100453274895857),
#  ('Kaisaniemenpuisto', 0.0036511354086210643),
#  ('Töölönlahdenkatu', 0.003633327428329503),
#  ('Laajalahden aukio', 0.003570207249204389),
#  ('Ympyrätalo', 0.0032789587794761735),
#  ('Rautatientori / länsi', 0.003148318188416619),
#  ('Baana', 0.0030631415349939243),
#  ('Rautatientori / itä', 0.003002706236461327),
#  ('Sörnäinen (M)', 0.0029796806651420107),
#  ('Huopalahdentie', 0.002949286899754881),
#  ('Vanha kirkkopuisto', 0.0029107449545250114),
#  ('Paciuksenkaari', 0.002804800410135715),
#  ('Aalto-yliopisto (M), Korkeakouluaukio', 0.0027415454368987196),
#  ('Korjaamo', 0.0027310238797426914),
#  ('Fleminginkatu', 0.0026942958825671164),
#  ('Marian sairaala', 0.0026873487033706473),
#  ('Munkkiniemen aukio', 0.002660108114456435),
#  ('Töölöntulli', 0.0026364136192060894),
#  ('Lauttasaaren ostoskeskus', 0.002574327282882113),
#  ('Mäkelänkatu', 0.0025172077219486563),
#  ('Diakoniapuisto', 0.0024797064692476055),
#  ('Messeniuksenkatu', 0.0024759525444717685),
#  ('Lehtisaarentie', 0.0024661724147950316),
#  ('Jämeräntaival', 0.0024464934544269168),
#  ('Kalasatama (M)', 0.0024331740224561313),
#  ('Länsisatamankatu', 0.0024306625071297866),
#  ('Hietalahdentori', 0.0023872909899829934),
#  ('Kanavaranta', 0.002386879541124579),
#  ('Tilkanvierto', 0.0023688055460388555),
#  ('Esterinportti', 0.0023463632517343076),
#  ('Eteläesplanadi', 0.0023206065639379014),
#  ('Otaranta', 0.0022320753281096627),
#  ('Jätkäsaarenlaituri', 0.002223643905950074),
#  ('Eteläinen Hesperiankatu', 0.002214402130765328),
#  ('Rautatieläisenkatu', 0.0022025052672119847),
#  ('Saunalahdentie', 0.0021881763528010956),
#  ('Kuusitie', 0.0021853889605549072),
#  ('Pernajantie', 0.0021837211248283534),
#  ('Paciuksenkatu', 0.0021831717817452976),
#  ('Leppäsuonaukio', 0.002177846747241664),
#  ('Keilaniemi (M)', 0.002139487756830966),
#  ('Lauttasaarensilta', 0.0021391187188485403),
#  ('Hakaniemi (M)', 0.002133426482602941),
#  ('Linnanmäki', 0.0021319318300390164),
#  ('Ooppera', 0.0021318040558902275),
#  ('Unioninkatu', 0.0021049838294084243),
#  ('Ratapihantie', 0.002103454836850962),
#  ('Sepänkatu', 0.0020943820052365075),
#  ('Brahen kenttä', 0.0020707157793051546),
#  ('Lastenlehto', 0.0020551767410675755),
#  ('Nordenskiöldinaukio', 0.0020371408417447527),
#  ('Hertanmäenkatu', 0.002028537374516147),
#  ('Kaivopuisto', 0.002024490339741279),
#  ('Luoteisväylä', 0.002011066703442609),
#  ('Keilaranta', 0.0019980283809704004),
#  ('Kustaankatu', 0.0019904090061743486),
#  ('Töölöntori', 0.0019811052202387954),
#  ('Tenholantie', 0.0019498914038287647),
#  ('Näkinsilta', 0.0019324008281518322),
#  ('Meilahden sairaala', 0.0019250599079428164),
#  ('Porthania', 0.001918393569161787),
#  ('Arabian kauppakeskus', 0.0019004626915740215),
#  ('Elimäenkatu', 0.0018952874650241319),
#  ('Keilalahti', 0.001887227581826317),
#  ('Seurasaari', 0.0018853625937699163),
#  ('Gyldenintie', 0.001882810581465811),
#  ('Kiasma', 0.0018812004908999372),
#  ('Olympiastadion', 0.0018703839352315272),
#  ('Torpanranta', 0.0018540277291105832),
#  ('Puistokaari', 0.0018295149783092316),
#  ('Gebhardinaukio', 0.0018218171541055682),
#  ('Teljäntie', 0.0018019127433989905),
#  ('Vihdintie', 0.001798615566363728),
#  ('Kesäkatu', 0.0017930325388682987),
#  ('Haagan tori', 0.0017838244790348192),
#  ('Uimastadion', 0.0017807905809051963),
#  ('Vilhonvuorenkatu', 0.0017733211680820012),
#  ('Varsapuistikko', 0.0017658914594107997),
#  ('Teurastamo', 0.0017503044325873633),
#  ('Sateentie', 0.0017416961727857944),
#  ('Venttiilikuja', 0.0017314720178730428),
#  ('Mannerheimintie', 0.00171760091111395),
#  ('Laajalahden keskus', 0.0017005241958026572),
#  ('Apollonkatu', 0.0016983287937033687),
#  ('Teollisuuskatu', 0.0016875453712074345),
#  ('Isoisänsilta', 0.0016820005990305516),
#  ('Koskelantie', 0.0016720186257510455),
#  ('Kalevankatu', 0.0016654329341154828),
#  ('Kapteeninpuistikko', 0.001644636917140251),
#  ('Brahen puistikko', 0.001644053202737938),
#  ('Lintulahdenkatu', 0.001611365762790329),
#  ('Pasilan asema', 0.0016085246035503948),
#  ('Jalavatie', 0.0016048519139733666),
#  ('Leppävaaranaukio', 0.0015769353384095612),
#  ('Arabiankatu', 0.001569100818765491),
#  ('Aalto-yliopisto (M), Tietotie', 0.0015585121417633976),
#  ('Stenbäckinkatu', 0.0015351099266283066),
#  ('Perämiehenkatu', 0.0015278750736817581),
#  ('Tilkantori', 0.0015201610269842045),
#  ('Tapionaukio', 0.001477734147713153),
#  ('Albertinkatu', 0.001470272705228736),
#  ('Rajasaarentie', 0.0014490882601666771),
#  ('Jäähalli', 0.0014460016698768401),
#  ('Liisanpuistikko', 0.0014447260185925263),
#  ('Heikkilänaukio', 0.0014111454293694152),
#  ('Töölönkatu', 0.0014055206646974795),
#  ('Annankatu', 0.0014028629761571362),
#  ('Otsolahti', 0.0014025341977190557),
#  ('Haapaniemenkatu', 0.0014001661002409627),
#  ('Verkatehtaanpuisto', 0.0013851517838232204),
#  ('Töölönlahden puisto', 0.0013845957410329637),
#  ('Valimotie', 0.0013680430422424337),
#  ('Ulvilantie', 0.0013621472012000555),
#  ('Viiskulma', 0.0013575323297517626),
#  ('Toinen linja', 0.0013358767509427706),
#  ('Kriikunakuja', 0.0013326142491423584),
#  ('Tekniikantie', 0.0013322286520889002),
#  ('Sähkömies', 0.0013273990293959964),
#  ('Opastinsilta', 0.0013271496353510859),
#  ('Kuikkarinne', 0.0013233198628737552),
#  ('Arielinkatu', 0.0013143280591544414),
#  ('Sammonpuistikko', 0.0012978672243822282),
#  ('Senaatintori', 0.0012914609098187496),
#  ('Hollolantie', 0.0012853959486800665),
#  ('Hanasaari', 0.0012830305873266128),
#  ('Muusantori', 0.0012829994873657278),
#  ('Urheilupuisto (M)', 0.001282614092073244),
#  ('Korppaanmäentie', 0.0012510753156961035),
#  ('Käpylän asema', 0.0012333902881590212),
#  ('Tunnelitie', 0.001232013432361304),
#  ('Paavalinpuisto', 0.0012288922019661698),
#  ('Päijänteentie', 0.0012280547940733363),
#  ('Hietaniemenkatu', 0.001225924103937491),
#  ('Kiskontie', 0.0012226761025584394),
#  ('Niittykumpu (M)', 0.001221420623918096),
#  ('Erottajan aukio', 0.0012175368544108513),
#  ('Velodrominrinne', 0.0011865280138458121),
#  ('Tyynenmerenkatu', 0.0011865100578652007),
#  ('Intiankatu', 0.001184997271494349),
#  ('Huopalahden asema', 0.001179275190498254),
#  ('Leppävaarankäytävä', 0.0011611866264021242),
#  ('Ratsutori', 0.001158948323359313),
#  ('Heikkiläntie', 0.0011558290433232087),
#  ('Mäntyviita', 0.0011554103048378977),
#  ('Betonimies', 0.0011515928404984535),
#  ('Käpyläntie', 0.0011510424079193271),
#  ('Takomotie', 0.0011296812477167495),
#  ('Westendinasema', 0.0011291414487471186),
#  ('Kauppakorkeakoulu', 0.0011255278143538444),
#  ('Karhupuisto', 0.0011097030742756064),
#  ('Metsänneidonpolku', 0.001104975164380851),
#  ('Piispansilta', 0.0011043581619402329),
#  ('Niittymaa', 0.0010953857091132713),
#  ('Vanha Viertotie', 0.0010928864743446783),
#  ('Eerikinkatu', 0.001078489696875809),
#  ('Kulttuuriaukio', 0.0010767828166262032),
#  ('Itälahdenkatu', 0.0010732753741883535),
#  ('Hernesaarenranta', 0.0010728410542783604),
#  ('Kulosaari (M)', 0.001071237627711428),
#  ('Maistraatintori', 0.0010665263614107884),
#  ('Näyttelijäntie', 0.0010575759567743792),
#  ('Kalevalantie', 0.0010485272496440854),
#  ('Länsituuli', 0.0010475697568768758),
#  ('Pohjankulma', 0.0010425343654526047),
#  ('Pohjois-Haagan asema', 0.0010357931787718824),
#  ('Kirjurinkuja', 0.0010303789142409078),
#  ('Pajamäki', 0.0010297663687690204),
#  ('Revontulentie', 0.0010126538681666326),
#  ('Radiokatu', 0.0009921959760048498),
#  ('Thalianaukio', 0.0009920294640198694),
#  ('Kansallismuseo', 0.0009670364827896772),
#  ('Mankkaanaukio', 0.000933458364567469),
#  ('Jännetie', 0.0009309037960754935),
#  ('Salmisaarenranta', 0.000925671310050892),
#  ('Herttoniemi (M)', 0.0009194864641689878),
#  ('Säteri', 0.0009192061517715724),
#  ('Pohjolanaukio', 0.0009147827174204201),
#  ('Viikin tiedepuisto', 0.000899277836685933),
#  ('Ruskeasuon varikko', 0.0008867052425784287),
#  ('Relanderinaukio', 0.0008863635447438826),
#  ('Ahertajantie', 0.0008816152578653499),
#  ('Louhentori', 0.0008803915093337078),
#  ('Gallen-Kallelan tie', 0.0008736719194619327),
#  ('Majurinkulma', 0.0008693588682541619),
#  ('Ilmalan asema', 0.000863431452061846),
#  ('Maarinranta', 0.0008593096119711908),
#  ('Rummunlyöjänkatu', 0.0008568031815837159),
#  ('Lepolantie', 0.0008473512165966426),
#  ('Innopoli', 0.000841477729147672),
#  ('Ritarikatu', 0.0008399477021559472),
#  ('Mankkaanlaaksontie', 0.000837521861680573),
#  ('Oulunkylän asema', 0.0008352540099516301),
#  ('Tietäjä', 0.0008292675534833491),
#  ('Vanha Kauppahalli', 0.0008157209372779338),
#  ('Katariina Saksilaisen katu', 0.0008103377160171639),
#  ('Petter Wetterin tie', 0.0008032535137792097),
#  ('Lumivaarantie', 0.0007991800973489882),
#  ('Suomenlahdentie', 0.0007978325171022168),
#  ('Merihaka', 0.000794248685036788),
#  ('Hakalehto', 0.0007940534999091829),
#  ('Juhana Herttuan tie', 0.0007788975303113139),
#  ('Eläinmuseo', 0.0007681162403138432),
#  ('Läkkitori', 0.0007642641057313946),
#  ('Mustikkamaa', 0.0007573085307745282),
#  ('Pitäjänmäen asema', 0.0007569128487416017),
#  ('Melkonkuja', 0.0007520946928889021),
#  ('Vesakkotie', 0.0007317782374759489),
#  ('Marttila', 0.0007295967973829884),
#  ('Westendintie', 0.0006972749478452874),
#  ('Mäkkylän asema', 0.0006932798341679489),
#  ('Länsisatamankuja', 0.0006889599552540353),
#  ('Viikin normaalikoulu', 0.0006884303988546862),
#  ('Cygnaeuksenkatu', 0.000687220036462179),
#  ('Kylävoudintie', 0.0006753735650622788),
#  ('Designmuseo', 0.000671631563187179),
#  ('Säterinniitty', 0.000663090642930128),
#  ('Valimon asema', 0.0006593052153093689),
#  ('Oravannahkatori', 0.000653802354477289),
#  ('Laivasillankatu', 0.0006461880895804569),
#  ('Mellstenintie', 0.0006418962667635419),
#  ('Otto Brandtin tie', 0.0006382006441546948),
#  ('Kasarmitori', 0.0006297330081519797),
#  ('Herttoniemenranta', 0.0006176958714404348),
#  ('Kalkkipellonmäki', 0.0006148531260098919),
#  ('Ehrenströmintie', 0.0006135135867583561),
#  ('Itäkeskus (M)', 0.0006053641272220228),
#  ('A.I. Virtasen aukio', 0.0006037271050498418),
#  ('Kaapelitehdas', 0.0005998469624050674),
#  ('Tapiolan urheilupuisto', 0.0005961726704427916),
#  ('Herttoniemen kirkko', 0.0005928794723190238),
#  ('Olarinluoma', 0.0005797916394910598),
#  ('Sofianlehdonkatu', 0.0005780334939209556),
#  ('Etuniementie', 0.0005692668816822417),
#  ('Huovitie', 0.0005657459464638851),
#  ('Yhdyskunnankuja', 0.0005593099094657047),
#  ('Laivalahden puistotie', 0.0005488922022468685),
#  ('Golfpolku', 0.0005431024080910694),
#  ('Pohjolankatu', 0.0005414955507014698),
#  ('Maunula', 0.0005390107731484605),
#  ('Tupasaarentie', 0.0005357251067972588),
#  ('Hernepellontie', 0.0005330401484858745),
#  ('Linnakepolku', 0.0005301302153691385),
#  ('Hämeenlinnanväylä', 0.000525534351287671),
#  ('Abraham Wetterin tie', 0.0005225695142454215),
#  ('Muotoilijankatu', 0.0005193836243877406),
#  ('Siilitie 9', 0.0005152518587062348),
#  ('Pihlajamäki', 0.0005095423200829101),
#  ('Säterinrinne', 0.0005058030033551682),
#  ('Eränkävijäntori', 0.0005036260651441218),
#  ('Postipuun koulu', 0.0005014265704901436),
#  ('Ida Aalbergin tie', 0.0004990476905682762),
#  ('Agronominkatu', 0.0004917788176503915),
#  ('Koivu-Mankkaa', 0.00048313251901124565),
#  ('Tuulimäki', 0.00048111798095581477),
#  ('Aulangontie', 0.00047495799556264467),
#  ('Haukilahdenaukio', 0.0004726692125065181),
#  ('Kuunkatu', 0.00047070979801230314),
#  ('Vallilan\xa0varikko', 0.0004695973368808646),
#  ('Koskelan varikko', 0.00046387650510061726),
#  ('Asentajanpuisto', 0.0004615979562027267),
#  ('Matinkartanontie', 0.00045811506563339785),
#  ('Siltavoudintie', 0.0004519424084235933),
#  ('Kustaankartano', 0.0004377620166071402),
#  ('Upseerinkatu', 0.00043300012451628477),
#  ('Siilitie (M)', 0.0004314342876710626),
#  ('Linnuntie', 0.00041644421666099093),
#  ('Toppelundinportti', 0.000415765854915305),
#  ('Painiitty', 0.0004087037650292861),
#  ('Haukilahdenranta', 0.00039767375829633764),
#  ('Piispankallio', 0.0003974944129063079),
#  ('Mäkitorpantie', 0.0003950627364590913),
#  ('Muurarinkuja', 0.00039241982716792196),
#  ('Auringonkatu', 0.00039219791880516276),
#  ('Agnetankuja', 0.0003874484050313576),
#  ('Myllypuro (M)', 0.0003829130379437135),
#  ('Leppävaaran urheilupuisto', 0.00038192342076728136),
#  ('Ruomelantie', 0.0003673307449873815),
#  ('Lukutori', 0.00036704346327244965),
#  ('Nelikkotie', 0.00035162964838690076),
#  ('Laajasalon ostoskeskus', 0.00034781237347868924),
#  ('Nokkala', 0.0003449662025341925),
#  ('Mastokatu', 0.0003448792939749094),
#  ('Isosaarentie', 0.00034147229166796577),
#  ('Korkeasaari', 0.000341363173127799),
#  ('Vallipolku', 0.0003410670381124997),
#  ('Piispanportti', 0.000339322334817722),
#  ('Komeetankatu', 0.0003361001292483854),
#  ('Hagalundinpuisto', 0.0003263074672812169),
#  ('Käskynhaltijantie', 0.00032593556975593033),
#  ('Porolahden koulu', 0.000322567137643069),
#  ('Voikukantie', 0.0003200312528808037),
#  ('Margareetankuja', 0.0003148483441877307),
#  ('Komentajankatu', 0.0003093956848514947),
#  ('Tammisalon aukio', 0.0003016076831525308),
#  ('Von Daehnin katu', 0.00029233178787700653),
#  ('Leppävaaran uimahalli', 0.00028552621403727513),
#  ('Tontunmäentie', 0.0002783705612802471),
#  ('Kirkkoherrantie', 0.00027820058204459545),
#  ('Roihupelto', 0.00027807717653321795),
#  ('Vallikatu', 0.000272323620084101),
#  ('Tulisuontie', 0.00026985670611257863),
#  ('Friisilänaukio', 0.000257531711037518),
#  ('Suurpellonaukio', 0.0002556551945981655),
#  ('Toppelundintie', 0.0002515584432245177),
#  ('Hauenkalliontie', 0.00024653364300237276),
#  ('Merisotilaantori', 0.0002452296079949291),
#  ('Reiherintie', 0.00023735184577000694),
#  ('Lystimäki', 0.0002371033635564628),
#  ('Gransinmäki', 0.0002341041057458776),
#  ('Peukaloisentie', 0.00023209326738495625),
#  ('Kutsuntatie', 0.00023095846708269733),
#  ('Matinlahdenranta', 0.00021689360567138895),
#  ('Tiistinkallio', 0.00021441372463217766),
#  ('Elfvik', 0.00020929430353796026),
#  ('Siilitie 13', 0.00020400620018199632),
#  ('Ruutikatu', 0.0001992218259304016),
#  ('Humalniementie', 0.0001974708967904082),
#  ('Itäportti', 0.00019639431480024454),
#  ('Prinsessantie', 0.0001925577563990283),
#  ('Nuottaniementie', 0.00019031167093654357),
#  ('Puotila (M)', 0.0001874788375863507),
#  ('Matinkyläntie', 0.00017811774806036402),
#  ('Puotilantie', 0.00017535746934476236),
#  ('Puotinharju', 0.00017281201036056053),
#  ('Marjaniementie', 0.0001710817092874165),
#  ('Alakiventie', 0.00016970711467040125),
#  ('Mamsellimyllynkatu', 0.00016615977450788811),
#  ('Sepetlahdentie', 0.0001656861385687439),
#  ('Hauenkallio', 0.00016175847256921826),
#  ('Länsiterminaali', 0.0001515459012354191),
#  ('Karhulantie', 0.00014566883048635254),
#  ('Gunillantie', 0.0001433306988850103),
#  ('Puotilan ostoskeskus', 0.00013507730325835633),
#  ('Orpaanporras', 0.00013446583684623416),
#  ('Orionintie', 0.00013174109730070243),
#  ('Avaruuskatu', 0.00011653968017143761),
#  ('Puotinkylän kartano', 0.00010756478814932272),
#  ('Lystimäensilta', 0.00010543620644163661),
#  ('Tiistiläntie', 0.00010418842579185417),
#  ('Marjaniemi', 8.744420343111479e-05),
#  ('Itäkeskus Metrovarikko', 7.897254646768258e-05),
#  ('Outotec', 6.228509005864044e-05),
#  ('Haakoninlahdenkatu', 5.1174595018976244e-05),
#  ('Derby Business Park', 4.5250769492512144e-05)]

# %%
for b in sorted_betweenness[:5]:
        print(b)
# Out:
# ('Haukilahdenkatu', 0.00713446536080233)
# ('Itämerentori', 0.00489579608404948)
# ('Kamppi (M)', 0.0037203436342368394)
# ('Narinkka', 0.0037100453274895857)
# ('Kaisaniemenpuisto', 0.0036511354086210643)

# %% [markdown]
# Haukilahdenkatu has highest betweenness centrality. This is no brainer that Haukilahdenkatu has both highest degree centrality and betweenness centrality because as Haukilahdenkatu has highest no of degrees that means it also most likely must be connecting different nodes. Itamerentori also have high betweenness centrality.

# %%
t5=sorted([d for n, d in sorted_betweenness],reverse=True)
for d in t5[:5]:
        print(d)
# Out:
# 0.00713446536080233
# 0.00489579608404948
# 0.0037203436342368394
# 0.0037100453274895857
# 0.0036511354086210643

# %%
degreeCount = collections.Counter(t5)
deg, cnt = zip(*degreeCount.items())

# %%
fig,ax=plt.subplots(figsize=(15,7))

plt.scatter(deg,cnt,color='blue')

# %% [markdown]
# Closeness Centrality

# %%
closeness=nx.closeness_centrality(G)
sorted_closeness=sorted(closeness.items(),key=itemgetter(1),reverse=True)
sorted_closeness
# Out:
# [('Haukilahdenkatu', 0.9453551912568307),
#  ('Itämerentori', 0.9105263157894737),
#  ('Laajalahden aukio', 0.8894601542416453),
#  ('Kamppi (M)', 0.8826530612244898),
#  ('Töölönlahdenkatu', 0.8781725888324873),
#  ('Paciuksenkaari', 0.871536523929471),
#  ('Ympyrätalo', 0.8693467336683417),
#  ('Kaisaniemenpuisto', 0.8693467336683417),
#  ('Huopalahdentie', 0.8693467336683417),
#  ('Rautatientori / länsi', 0.8671679197994987),
#  ('Narinkka', 0.8628428927680798),
#  ('Korjaamo', 0.858560794044665),
#  ('Munkkiniemen aukio', 0.858560794044665),
#  ('Töölöntulli', 0.858560794044665),
#  ('Tilkanvierto', 0.8564356435643564),
#  ('Baana', 0.854320987654321),
#  ('Rautatientori / itä', 0.8522167487684729),
#  ('Sörnäinen (M)', 0.8501228501228502),
#  ('Diakoniapuisto', 0.8480392156862745),
#  ('Fleminginkatu', 0.8439024390243902),
#  ('Vanha kirkkopuisto', 0.8439024390243902),
#  ('Aalto-yliopisto (M), Korkeakouluaukio', 0.8439024390243902),
#  ('Messeniuksenkatu', 0.8439024390243902),
#  ('Lehtisaarentie', 0.8439024390243902),
#  ('Eteläinen Hesperiankatu', 0.8418491484184915),
#  ('Saunalahdentie', 0.8398058252427184),
#  ('Kuusitie', 0.837772397094431),
#  ('Marian sairaala', 0.837772397094431),
#  ('Tenholantie', 0.8357487922705314),
#  ('Esterinportti', 0.8337349397590361),
#  ('Ooppera', 0.8337349397590361),
#  ('Paciuksenkatu', 0.8337349397590361),
#  ('Hietalahdentori', 0.8317307692307693),
#  ('Meilahden sairaala', 0.829736211031175),
#  ('Rautatieläisenkatu', 0.829736211031175),
#  ('Nordenskiöldinaukio', 0.829736211031175),
#  ('Lauttasaaren ostoskeskus', 0.829736211031175),
#  ('Ratapihantie', 0.829736211031175),
#  ('Linnanmäki', 0.8277511961722488),
#  ('Jätkäsaarenlaituri', 0.8257756563245824),
#  ('Torpanranta', 0.8257756563245824),
#  ('Olympiastadion', 0.8238095238095238),
#  ('Kesäkatu', 0.8238095238095238),
#  ('Hertanmäenkatu', 0.8238095238095238),
#  ('Seurasaari', 0.8238095238095238),
#  ('Länsisatamankatu', 0.8218527315914489),
#  ('Leppäsuonaukio', 0.8218527315914489),
#  ('Apollonkatu', 0.8218527315914489),
#  ('Brahen kenttä', 0.8199052132701422),
#  ('Otaranta', 0.8199052132701422),
#  ('Vihdintie', 0.8199052132701422),
#  ('Kiasma', 0.817966903073286),
#  ('Eteläesplanadi', 0.817966903073286),
#  ('Jämeräntaival', 0.817966903073286),
#  ('Lastenlehto', 0.8160377358490566),
#  ('Mäkelänkatu', 0.8160377358490566),
#  ('Kanavaranta', 0.8141176470588235),
#  ('Venttiilikuja', 0.8141176470588235),
#  ('Kalasatama (M)', 0.812206572769953),
#  ('Hakaniemi (M)', 0.812206572769953),
#  ('Elimäenkatu', 0.812206572769953),
#  ('Töölöntori', 0.812206572769953),
#  ('Uimastadion', 0.812206572769953),
#  ('Porthania', 0.810304449648712),
#  ('Stenbäckinkatu', 0.810304449648712),
#  ('Unioninkatu', 0.810304449648712),
#  ('Tilkantori', 0.810304449648712),
#  ('Pernajantie', 0.810304449648712),
#  ('Gebhardinaukio', 0.8084112149532711),
#  ('Pasilan asema', 0.8084112149532711),
#  ('Haagan tori', 0.8084112149532711),
#  ('Jalavatie', 0.8065268065268065),
#  ('Koskelantie', 0.8046511627906977),
#  ('Arabian kauppakeskus', 0.802784222737819),
#  ('Mannerheimintie', 0.802784222737819),
#  ('Sepänkatu', 0.802784222737819),
#  ('Kustaankatu', 0.8009259259259259),
#  ('Luoteisväylä', 0.8009259259259259),
#  ('Näkinsilta', 0.7990762124711316),
#  ('Varsapuistikko', 0.7990762124711316),
#  ('Teollisuuskatu', 0.7990762124711316),
#  ('Keilaniemi (M)', 0.7990762124711316),
#  ('Teljäntie', 0.7990762124711316),
#  ('Töölönkatu', 0.7972350230414746),
#  ('Rajasaarentie', 0.7972350230414746),
#  ('Jäähalli', 0.7972350230414746),
#  ('Ulvilantie', 0.7972350230414746),
#  ('Keilaranta', 0.7972350230414746),
#  ('Brahen puistikko', 0.7954022988505747),
#  ('Kaivopuisto', 0.7954022988505747),
#  ('Gyldenintie', 0.7954022988505747),
#  ('Teurastamo', 0.7954022988505747),
#  ('Töölönlahden puisto', 0.7935779816513762),
#  ('Lauttasaarensilta', 0.7935779816513762),
#  ('Korppaanmäentie', 0.7917620137299771),
#  ('Vilhonvuorenkatu', 0.7917620137299771),
#  ('Kriikunakuja', 0.7917620137299771),
#  ('Arabiankatu', 0.7917620137299771),
#  ('Kalevankatu', 0.7917620137299771),
#  ('Toinen linja', 0.7917620137299771),
#  ('Kiskontie', 0.7899543378995434),
#  ('Keilalahti', 0.7899543378995434),
#  ('Isoisänsilta', 0.7881548974943052),
#  ('Sammonpuistikko', 0.7863636363636364),
#  ('Opastinsilta', 0.7863636363636364),
#  ('Lintulahdenkatu', 0.7845804988662132),
#  ('Hietaniemenkatu', 0.7845804988662132),
#  ('Tunnelitie', 0.7845804988662132),
#  ('Liisanpuistikko', 0.781038374717833),
#  ('Puistokaari', 0.781038374717833),
#  ('Karhupuisto', 0.781038374717833),
#  ('Hollolantie', 0.7792792792792793),
#  ('Viiskulma', 0.7775280898876404),
#  ('Paavalinpuisto', 0.7775280898876404),
#  ('Verkatehtaanpuisto', 0.7775280898876404),
#  ('Velodrominrinne', 0.7775280898876404),
#  ('Haapaniemenkatu', 0.7775280898876404),
#  ('Radiokatu', 0.7757847533632287),
#  ('Perämiehenkatu', 0.7757847533632287),
#  ('Intiankatu', 0.7757847533632287),
#  ('Albertinkatu', 0.7757847533632287),
#  ('Muusantori', 0.7757847533632287),
#  ('Kauppakorkeakoulu', 0.7740492170022372),
#  ('Kapteeninpuistikko', 0.7740492170022372),
#  ('Annankatu', 0.7740492170022372),
#  ('Laajalahden keskus', 0.7740492170022372),
#  ('Maistraatintori', 0.7740492170022372),
#  ('Päijänteentie', 0.7706013363028953),
#  ('Vanha Viertotie', 0.7706013363028953),
#  ('Heikkilänaukio', 0.7706013363028953),
#  ('Käpyläntie', 0.7706013363028953),
#  ('Huopalahden asema', 0.7688888888888888),
#  ('Senaatintori', 0.7654867256637168),
#  ('Käpylän asema', 0.7654867256637168),
#  ('Valimotie', 0.7654867256637168),
#  ('Arielinkatu', 0.7654867256637168),
#  ('Ruskeasuon varikko', 0.7637969094922737),
#  ('Kuikkarinne', 0.7637969094922737),
#  ('Takomotie', 0.7637969094922737),
#  ('Kansallismuseo', 0.7604395604395604),
#  ('Aalto-yliopisto (M), Tietotie', 0.7604395604395604),
#  ('Heikkiläntie', 0.7587719298245614),
#  ('Erottajan aukio', 0.7587719298245614),
#  ('Pohjolanaukio', 0.7538126361655774),
#  ('Tapionaukio', 0.7521739130434782),
#  ('Tyynenmerenkatu', 0.7505422993492408),
#  ('Salmisaarenranta', 0.7505422993492408),
#  ('Leppävaaranaukio', 0.7505422993492408),
#  ('Sateentie', 0.7505422993492408),
#  ('Hernesaarenranta', 0.7489177489177489),
#  ('Ilmalan asema', 0.7489177489177489),
#  ('Ritarikatu', 0.7473002159827213),
#  ('Eläinmuseo', 0.7456896551724138),
#  ('Thalianaukio', 0.7456896551724138),
#  ('Eerikinkatu', 0.7440860215053764),
#  ('Cygnaeuksenkatu', 0.7424892703862661),
#  ('Otsolahti', 0.7408993576017131),
#  ('Sähkömies', 0.7408993576017131),
#  ('Merihaka', 0.7408993576017131),
#  ('Kulosaari (M)', 0.7393162393162394),
#  ('Itälahdenkatu', 0.7393162393162394),
#  ('Länsisatamankuja', 0.7393162393162394),
#  ('Katariina Saksilaisen katu', 0.7346072186836518),
#  ('Betonimies', 0.7330508474576272),
#  ('Tekniikantie', 0.7330508474576272),
#  ('Pajamäki', 0.7330508474576272),
#  ('Gallen-Kallelan tie', 0.7315010570824524),
#  ('Juhana Herttuan tie', 0.729957805907173),
#  ('Pohjolankatu', 0.729957805907173),
#  ('Sofianlehdonkatu', 0.729957805907173),
#  ('Designmuseo', 0.728421052631579),
#  ('A.I. Virtasen aukio', 0.726890756302521),
#  ('Hanasaari', 0.726890756302521),
#  ('Huovitie', 0.726890756302521),
#  ('Näyttelijäntie', 0.726890756302521),
#  ('Leppävaarankäytävä', 0.7253668763102725),
#  ('Lepolantie', 0.7238493723849372),
#  ('Ratsutori', 0.7238493723849372),
#  ('Vesakkotie', 0.7238493723849372),
#  ('Mäntyviita', 0.7238493723849372),
#  ('Oulunkylän asema', 0.7238493723849372),
#  ('Kasarmitori', 0.7223382045929019),
#  ('Viikin tiedepuisto', 0.7223382045929019),
#  ('Vallilan\xa0varikko', 0.7223382045929019),
#  ('Laivasillankatu', 0.7208333333333333),
#  ('Westendinasema', 0.7208333333333333),
#  ('Pohjois-Haagan asema', 0.7208333333333333),
#  ('Herttoniemi (M)', 0.7178423236514523),
#  ('Jännetie', 0.7178423236514523),
#  ('Mustikkamaa', 0.7163561076604554),
#  ('Vanha Kauppahalli', 0.7163561076604554),
#  ('Relanderinaukio', 0.7163561076604554),
#  ('Majurinkulma', 0.7148760330578512),
#  ('Petter Wetterin tie', 0.7148760330578512),
#  ('Pitäjänmäen asema', 0.7148760330578512),
#  ('Urheilupuisto (M)', 0.7148760330578512),
#  ('Valimon asema', 0.7148760330578512),
#  ('Ehrenströmintie', 0.7134020618556701),
#  ('Kirjurinkuja', 0.7134020618556701),
#  ('Revontulentie', 0.7134020618556701),
#  ('Maunula', 0.7134020618556701),
#  ('Kaapelitehdas', 0.7134020618556701),
#  ('Länsituuli', 0.7119341563786008),
#  ('Piispansilta', 0.7104722792607803),
#  ('Säteri', 0.7104722792607803),
#  ('Kulttuuriaukio', 0.7090163934426229),
#  ('Melkonkuja', 0.7075664621676891),
#  ('Kylävoudintie', 0.7075664621676891),
#  ('Hämeenlinnanväylä', 0.7061224489795919),
#  ('Pohjankulma', 0.7046843177189409),
#  ('Muotoilijankatu', 0.7046843177189409),
#  ('Kalevalantie', 0.7032520325203252),
#  ('Niittykumpu (M)', 0.7004048582995951),
#  ('Metsänneidonpolku', 0.7004048582995951),
#  ('Marttila', 0.7004048582995951),
#  ('Koskelan varikko', 0.6975806451612904),
#  ('Niittymaa', 0.6947791164658634),
#  ('Mastokatu', 0.692),
#  ('Merisotilaantori', 0.692),
#  ('Otto Brandtin tie', 0.6892430278884463),
#  ('Herttoniemenranta', 0.6878727634194831),
#  ('Mäkkylän asema', 0.6878727634194831),
#  ('Hernepellontie', 0.6878727634194831),
#  ('Hakalehto', 0.6865079365079365),
#  ('Innopoli', 0.6851485148514852),
#  ('Siltavoudintie', 0.6837944664031621),
#  ('Läkkitori', 0.6837944664031621),
#  ('Ida Aalbergin tie', 0.6837944664031621),
#  ('Ahertajantie', 0.6824457593688363),
#  ('Mankkaanaukio', 0.6811023622047244),
#  ('Viikin normaalikoulu', 0.6797642436149313),
#  ('Maarinranta', 0.6797642436149313),
#  ('Louhentori', 0.6797642436149313),
#  ('Tietäjä', 0.6797642436149313),
#  ('Mäkitorpantie', 0.6784313725490196),
#  ('Rummunlyöjänkatu', 0.6784313725490196),
#  ('Laivalahden puistotie', 0.6771037181996086),
#  ('Tupasaarentie', 0.67578125),
#  ('Kustaankartano', 0.67578125),
#  ('Länsiterminaali', 0.6744639376218323),
#  ('Mankkaanlaaksontie', 0.6731517509727627),
#  ('Kalkkipellonmäki', 0.6718446601941748),
#  ('Herttoniemen kirkko', 0.6692456479690522),
#  ('Eränkävijäntori', 0.6692456479690522),
#  ('Suomenlahdentie', 0.667953667953668),
#  ('Lumivaarantie', 0.6666666666666666),
#  ('Korkeasaari', 0.6641074856046065),
#  ('Abraham Wetterin tie', 0.6628352490421456),
#  ('Pihlajamäki', 0.6628352490421456),
#  ('Yhdyskunnankuja', 0.6628352490421456),
#  ('Aulangontie', 0.6615678776290631),
#  ('Asentajanpuisto', 0.6615678776290631),
#  ('Westendintie', 0.6615678776290631),
#  ('Oravannahkatori', 0.6615678776290631),
#  ('Kirkkoherrantie', 0.6603053435114504),
#  ('Mellstenintie', 0.6577946768060836),
#  ('Säterinniitty', 0.6565464895635673),
#  ('Tapiolan urheilupuisto', 0.6565464895635673),
#  ('Siilitie (M)', 0.6553030303030303),
#  ('Agronominkatu', 0.6553030303030303),
#  ('Käskynhaltijantie', 0.6540642722117203),
#  ('Golfpolku', 0.6528301886792452),
#  ('Linnakepolku', 0.6516007532956686),
#  ('Agnetankuja', 0.650375939849624),
#  ('Etuniementie', 0.649155722326454),
#  ('Itäkeskus (M)', 0.6479400749063671),
#  ('Upseerinkatu', 0.6455223880597015),
#  ('Tuulimäki', 0.6455223880597015),
#  ('Porolahden koulu', 0.6419294990723562),
#  ('Säterinrinne', 0.6419294990723562),
#  ('Painiitty', 0.6419294990723562),
#  ('Haukilahdenaukio', 0.6407407407407407),
#  ('Olarinluoma', 0.6372007366482505),
#  ('Muurarinkuja', 0.6360294117647058),
#  ('Siilitie 9', 0.6360294117647058),
#  ('Toppelundinportti', 0.634862385321101),
#  ('Hagalundinpuisto', 0.634862385321101),
#  ('Haukilahdenranta', 0.6313868613138686),
#  ('Kuunkatu', 0.6302367941712204),
#  ('Margareetankuja', 0.6302367941712204),
#  ('Postipuun koulu', 0.6302367941712204),
#  ('Matinkartanontie', 0.6302367941712204),
#  ('Linnuntie', 0.6290909090909091),
#  ('Koivu-Mankkaa', 0.6290909090909091),
#  ('Laajasalon ostoskeskus', 0.6290909090909091),
#  ('Komentajankatu', 0.6268115942028986),
#  ('Auringonkatu', 0.6256781193490054),
#  ('Tammisalon aukio', 0.6256781193490054),
#  ('Leppävaaran urheilupuisto', 0.6245487364620939),
#  ('Isosaarentie', 0.6245487364620939),
#  ('Nokkala', 0.6245487364620939),
#  ('Vallipolku', 0.6234234234234234),
#  ('Roihupelto', 0.6223021582733813),
#  ('Myllypuro (M)', 0.6200716845878136),
#  ('Ruomelantie', 0.6200716845878136),
#  ('Nelikkotie', 0.6200716845878136),
#  ('Piispankallio', 0.6189624329159212),
#  ('Piispanportti', 0.6178571428571429),
#  ('Von Daehnin katu', 0.6178571428571429),
#  ('Tulisuontie', 0.6156583629893239),
#  ('Lukutori', 0.6156583629893239),
#  ('Voikukantie', 0.6134751773049646),
#  ('Peukaloisentie', 0.6134751773049646),
#  ('Leppävaaran uimahalli', 0.6134751773049646),
#  ('Tontunmäentie', 0.6134751773049646),
#  ('Reiherintie', 0.6113074204946997),
#  ('Elfvik', 0.6113074204946997),
#  ('Friisilänaukio', 0.6102292768959435),
#  ('Hauenkalliontie', 0.6091549295774648),
#  ('Suurpellonaukio', 0.6091549295774648),
#  ('Kutsuntatie', 0.6091549295774648),
#  ('Komeetankatu', 0.6080843585237259),
#  ('Vallikatu', 0.6070175438596491),
#  ('Toppelundintie', 0.6070175438596491),
#  ('Lystimäki', 0.6059544658493871),
#  ('Humalniementie', 0.6038394415357766),
#  ('Siilitie 13', 0.6027874564459931),
#  ('Matinlahdenranta', 0.6017391304347826),
#  ('Itäportti', 0.5996533795493935),
#  ('Gransinmäki', 0.5986159169550173),
#  ('Matinkyläntie', 0.5975820379965457),
#  ('Hauenkallio', 0.5975820379965457),
#  ('Ruutikatu', 0.5955249569707401),
#  ('Mamsellimyllynkatu', 0.5945017182130584),
#  ('Puotila (M)', 0.5945017182130584),
#  ('Gunillantie', 0.5934819897084048),
#  ('Marjaniementie', 0.5934819897084048),
#  ('Tiistinkallio', 0.5924657534246576),
#  ('Prinsessantie', 0.590443686006826),
#  ('Orionintie', 0.590443686006826),
#  ('Nuottaniementie', 0.590443686006826),
#  ('Puotinharju', 0.590443686006826),
#  ('Puotilan ostoskeskus', 0.5884353741496599),
#  ('Lystimäensilta', 0.5874363327674024),
#  ('Orpaanporras', 0.5874363327674024),
#  ('Karhulantie', 0.5854483925549916),
#  ('Avaruuskatu', 0.5834738617200674),
#  ('Sepetlahdentie', 0.5824915824915825),
#  ('Puotilantie', 0.5815126050420169),
#  ('Alakiventie', 0.5795644891122278),
#  ('Tiistiläntie', 0.5776293823038398),
#  ('Outotec', 0.571900826446281),
#  ('Puotinkylän kartano', 0.570957095709571),
#  ('Marjaniemi', 0.5681444991789819),
#  ('Haakoninlahdenkatu', 0.5607779578606159),
#  ('Derby Business Park', 0.5598705501618123),
#  ('Itäkeskus Metrovarikko', 0.5571658615136876)]

# %%
for t in sorted_closeness[:5]:
        print(t)
# Out:
# ('Haukilahdenkatu', 0.9453551912568307)
# ('Itämerentori', 0.9105263157894737)
# ('Laajalahden aukio', 0.8894601542416453)
# ('Kamppi (M)', 0.8826530612244898)
# ('Töölönlahdenkatu', 0.8781725888324873)

# %% [markdown]
# Haukilahdenkatu has the highest closeness centrality. This is also given since Haukilahdenkatu has the highest number of degrees which means people take frequent trips to Haukilahdenkatu. One of the major reasons for this is Haukilahdenkatu must be at the center of town so it is in close proximity to the people of Helsinki due to which they're making frequent trips. Apart from Haukilahdenkatu, Itämerentori and Laajalahden aukio also have high closeness centrality

# %%
t6=sorted([d for n,d in sorted_closeness],reverse=True)
degreeCount = collections.Counter(t6)
deg, cnt = zip(*degreeCount.items())

# %%
degreeCount
# Out:
# Counter({0.5571658615136876: 1,
#          0.5598705501618123: 1,
#          0.5607779578606159: 1,
#          0.5681444991789819: 1,
#          0.570957095709571: 1,
#          0.571900826446281: 1,
#          0.5776293823038398: 1,
#          0.5795644891122278: 1,
#          0.5815126050420169: 1,
#          0.5824915824915825: 1,
#          0.5834738617200674: 1,
#          0.5854483925549916: 1,
#          0.5874363327674024: 2,
#          0.5884353741496599: 1,
#          0.590443686006826: 4,
#          0.5924657534246576: 1,
#          0.5934819897084048: 2,
#          0.5945017182130584: 2,
#          0.5955249569707401: 1,
#          0.5975820379965457: 2,
#          0.5986159169550173: 1,
#          0.5996533795493935: 1,
#          0.6017391304347826: 1,
#          0.6027874564459931: 1,
#          0.6038394415357766: 1,
#          0.6059544658493871: 1,
#          0.6070175438596491: 2,
#          0.6080843585237259: 1,
#          0.6091549295774648: 3,
#          0.6102292768959435: 1,
#          0.6113074204946997: 2,
#          0.6134751773049646: 4,
#          0.6156583629893239: 2,
#          0.6178571428571429: 2,
#          0.6189624329159212: 1,
#          0.6200716845878136: 3,
#          0.6223021582733813: 1,
#          0.6234234234234234: 1,
#          0.6245487364620939: 3,
#          0.6256781193490054: 2,
#          0.6268115942028986: 1,
#          0.6290909090909091: 3,
#          0.6302367941712204: 4,
#          0.6313868613138686: 1,
#          0.634862385321101: 2,
#          0.6360294117647058: 2,
#          0.6372007366482505: 1,
#          0.6407407407407407: 1,
#          0.6419294990723562: 3,
#          0.6455223880597015: 2,
#          0.6479400749063671: 1,
#          0.649155722326454: 1,
#          0.650375939849624: 1,
#          0.6516007532956686: 1,
#          0.6528301886792452: 1,
#          0.6540642722117203: 1,
#          0.6553030303030303: 2,
#          0.6565464895635673: 2,
#          0.6577946768060836: 1,
#          0.6603053435114504: 1,
#          0.6615678776290631: 4,
#          0.6628352490421456: 3,
#          0.6641074856046065: 1,
#          0.6666666666666666: 1,
#          0.667953667953668: 1,
#          0.6692456479690522: 2,
#          0.6718446601941748: 1,
#          0.6731517509727627: 1,
#          0.6744639376218323: 1,
#          0.67578125: 2,
#          0.6771037181996086: 1,
#          0.6784313725490196: 2,
#          0.6797642436149313: 4,
#          0.6811023622047244: 1,
#          0.6824457593688363: 1,
#          0.6837944664031621: 3,
#          0.6851485148514852: 1,
#          0.6865079365079365: 1,
#          0.6878727634194831: 3,
#          0.6892430278884463: 1,
#          0.692: 2,
#          0.6947791164658634: 1,
#          0.6975806451612904: 1,
#          0.7004048582995951: 3,
#          0.7032520325203252: 1,
#          0.7046843177189409: 2,
#          0.7061224489795919: 1,
#          0.7075664621676891: 2,
#          0.7090163934426229: 1,
#          0.7104722792607803: 2,
#          0.7119341563786008: 1,
#          0.7134020618556701: 5,
#          0.7148760330578512: 5,
#          0.7163561076604554: 3,
#          0.7178423236514523: 2,
#          0.7208333333333333: 3,
#          0.7223382045929019: 3,
#          0.7238493723849372: 5,
#          0.7253668763102725: 1,
#          0.726890756302521: 4,
#          0.728421052631579: 1,
#          0.729957805907173: 3,
#          0.7315010570824524: 1,
#          0.7330508474576272: 3,
#          0.7346072186836518: 1,
#          0.7393162393162394: 3,
#          0.7408993576017131: 3,
#          0.7424892703862661: 1,
#          0.7440860215053764: 1,
#          0.7456896551724138: 2,
#          0.7473002159827213: 1,
#          0.7489177489177489: 2,
#          0.7505422993492408: 4,
#          0.7521739130434782: 1,
#          0.7538126361655774: 1,
#          0.7587719298245614: 2,
#          0.7604395604395604: 2,
#          0.7637969094922737: 3,
#          0.7654867256637168: 4,
#          0.7688888888888888: 1,
#          0.7706013363028953: 4,
#          0.7740492170022372: 5,
#          0.7757847533632287: 5,
#          0.7775280898876404: 5,
#          0.7792792792792793: 1,
#          0.781038374717833: 3,
#          0.7845804988662132: 3,
#          0.7863636363636364: 2,
#          0.7881548974943052: 1,
#          0.7899543378995434: 2,
#          0.7917620137299771: 6,
#          0.7935779816513762: 2,
#          0.7954022988505747: 4,
#          0.7972350230414746: 5,
#          0.7990762124711316: 5,
#          0.8009259259259259: 2,
#          0.802784222737819: 3,
#          0.8046511627906977: 1,
#          0.8065268065268065: 1,
#          0.8084112149532711: 3,
#          0.810304449648712: 5,
#          0.812206572769953: 5,
#          0.8141176470588235: 2,
#          0.8160377358490566: 2,
#          0.817966903073286: 3,
#          0.8199052132701422: 3,
#          0.8218527315914489: 3,
#          0.8238095238095238: 4,
#          0.8257756563245824: 2,
#          0.8277511961722488: 1,
#          0.829736211031175: 5,
#          0.8317307692307693: 1,
#          0.8337349397590361: 3,
#          0.8357487922705314: 1,
#          0.837772397094431: 2,
#          0.8398058252427184: 1,
#          0.8418491484184915: 1,
#          0.8439024390243902: 5,
#          0.8480392156862745: 1,
#          0.8501228501228502: 1,
#          0.8522167487684729: 1,
#          0.854320987654321: 1,
#          0.8564356435643564: 1,
#          0.858560794044665: 3,
#          0.8628428927680798: 1,
#          0.8671679197994987: 1,
#          0.8693467336683417: 3,
#          0.871536523929471: 1,
#          0.8781725888324873: 1,
#          0.8826530612244898: 1,
#          0.8894601542416453: 1,
#          0.9105263157894737: 1,
#          0.9453551912568307: 1})

# %%
fig,ax=plt.subplots(figsize=(15,7))

plt.scatter(deg,cnt,color='blue')

# %% [markdown]
# Eigenvector Centrality

# %%
eigenvector=nx.eigenvector_centrality(G)
eigenvector
# Out:
# {'A.I. Virtasen aukio': 0.05672856486146217,
#  'Aalto-yliopisto (M), Korkeakouluaukio': 0.06733202017952142,
#  'Aalto-yliopisto (M), Tietotie': 0.05628619889990218,
#  'Abraham Wetterin tie': 0.04139558392731589,
#  'Agnetankuja': 0.039227114567288425,
#  'Agronominkatu': 0.03946546163613187,
#  'Ahertajantie': 0.04132240063038489,
#  'Alakiventie': 0.020029676553132033,
#  'Albertinkatu': 0.06348755867114209,
#  'Annankatu': 0.0631231151147187,
#  'Apollonkatu': 0.0688388049015624,
#  'Arabian kauppakeskus': 0.06522257062240719,
#  'Arabiankatu': 0.06426006426877105,
#  'Arielinkatu': 0.06053886048451629,
#  'Asentajanpuisto': 0.04115859548348916,
#  'Aulangontie': 0.04197762557053689,
#  'Auringonkatu': 0.030566287870987394,
#  'Avaruuskatu': 0.01942739868394113,
#  'Baana': 0.0703772161520264,
#  'Betonimies': 0.053888497422833886,
#  'Brahen kenttä': 0.06761852156438213,
#  'Brahen puistikko': 0.06517202733966243,
#  'Cygnaeuksenkatu': 0.06015842814895531,
#  'Derby Business Park': 0.01789445723094259,
#  'Designmuseo': 0.05797588352209271,
#  'Diakoniapuisto': 0.07045072293117978,
#  'Eerikinkatu': 0.059606141395510605,
#  'Ehrenströmintie': 0.05534864234977581,
#  'Elfvik': 0.02951524336988557,
#  'Elimäenkatu': 0.0667884006261144,
#  'Eläinmuseo': 0.06053368913873151,
#  'Erottajan aukio': 0.06122749683065773,
#  'Eränkävijäntori': 0.042642459997965766,
#  'Esterinportti': 0.06913853195912492,
#  'Eteläesplanadi': 0.06715926928123443,
#  'Eteläinen Hesperiankatu': 0.07016493957170845,
#  'Etuniementie': 0.037321602998510124,
#  'Fleminginkatu': 0.06934003402155972,
#  'Friisilänaukio': 0.026463518178272773,
#  'Gallen-Kallelan tie': 0.05542898123260999,
#  'Gebhardinaukio': 0.0662049218642019,
#  'Golfpolku': 0.036783169747063735,
#  'Gransinmäki': 0.026019853831694945,
#  'Gunillantie': 0.025545779045645613,
#  'Gyldenintie': 0.06356250288456976,
#  'Haagan tori': 0.0668070882132391,
#  'Haakoninlahdenkatu': 0.016310849277556872,
#  'Haapaniemenkatu': 0.06303713794188333,
#  'Hagalundinpuisto': 0.034507501533756174,
#  'Hakalehto': 0.043725127661111154,
#  'Hakaniemi (M)': 0.06614346269024605,
#  'Hanasaari': 0.051108773650122216,
#  'Hauenkallio': 0.023535770539478716,
#  'Hauenkalliontie': 0.02686306734638715,
#  'Haukilahdenaukio': 0.03367478335069723,
#  'Haukilahdenkatu': 0.07518513059120188,
#  'Haukilahdenranta': 0.03214032386742077,
#  'Heikkilänaukio': 0.06138554786655396,
#  'Heikkiläntie': 0.060872102931950584,
#  'Hernepellontie': 0.047920955319093635,
#  'Hernesaarenranta': 0.059759656008819474,
#  'Hertanmäenkatu': 0.06849823482788403,
#  'Herttoniemen kirkko': 0.042694369551033166,
#  'Herttoniemenranta': 0.04697502516722144,
#  'Herttoniemi (M)': 0.0522488480923368,
#  'Hietalahdentori': 0.06870494152979886,
#  'Hietaniemenkatu': 0.06512140647639118,
#  'Hollolantie': 0.06367559355042138,
#  'Humalniementie': 0.02785350270568306,
#  'Huopalahden asema': 0.06244584037623229,
#  'Huopalahdentie': 0.0719509082791253,
#  'Huovitie': 0.05773975141874103,
#  'Hämeenlinnanväylä': 0.05376702582846494,
#  'Ida Aalbergin tie': 0.049190311704604105,
#  'Ilmalan asema': 0.06016878342567609,
#  'Innopoli': 0.04312974983707692,
#  'Intiankatu': 0.06309556157513486,
#  'Isoisänsilta': 0.06307985450050983,
#  'Isosaarentie': 0.032879434738896963,
#  'Itäkeskus (M)': 0.037442551823260915,
#  'Itäkeskus Metrovarikko': 0.014240220929167031,
#  'Itälahdenkatu': 0.0572269971964048,
#  'Itämerentori': 0.07377579534470748,
#  'Itäportti': 0.023382366615313725,
#  'Jalavatie': 0.06739924248102558,
#  'Juhana Herttuan tie': 0.056017610439563596,
#  'Jämeräntaival': 0.06394938976143735,
#  'Jännetie': 0.05377653919127387,
#  'Jätkäsaarenlaituri': 0.06825444399452196,
#  'Jäähalli': 0.06616086296173969,
#  'Kaapelitehdas': 0.055470839910981236,
#  'Kaisaniemenpuisto': 0.0709494753888168,
#  'Kaivopuisto': 0.06445952579301008,
#  'Kalasatama (M)': 0.06549059780635988,
#  'Kalevalantie': 0.046039751930234706,
#  'Kalevankatu': 0.06496210981908684,
#  'Kalkkipellonmäki': 0.04442768219908412,
#  'Kamppi (M)': 0.07251984669873815,
#  'Kanavaranta': 0.06631620142546028,
#  'Kansallismuseo': 0.06235576870735433,
#  'Kapteeninpuistikko': 0.06266910463936479,
#  'Karhulantie': 0.022464282478828267,
#  'Karhupuisto': 0.06459748214882034,
#  'Kasarmitori': 0.05688944633973931,
#  'Katariina Saksilaisen katu': 0.05610099288278749,
#  'Kauppakorkeakoulu': 0.06393882308505969,
#  'Keilalahti': 0.06132443493023254,
#  'Keilaniemi (M)': 0.062034740330332024,
#  'Keilaranta': 0.062086983338317484,
#  'Kesäkatu': 0.06860785571458859,
#  'Kiasma': 0.06808820205922236,
#  'Kirjurinkuja': 0.05136210623509907,
#  'Kirkkoherrantie': 0.04472424634088174,
#  'Kiskontie': 0.06580230000134017,
#  'Koivu-Mankkaa': 0.02909961665915719,
#  'Komeetankatu': 0.025345204312565,
#  'Komentajankatu': 0.03391736017073703,
#  'Korjaamo': 0.07136156405311259,
#  'Korkeasaari': 0.04488446512474505,
#  'Korppaanmäentie': 0.06578646335554308,
#  'Koskelan varikko': 0.05109854406736939,
#  'Koskelantie': 0.06599891139704013,
#  'Kriikunakuja': 0.06560566760892855,
#  'Kuikkarinne': 0.06003481100685547,
#  'Kulosaari (M)': 0.0562663215644168,
#  'Kulttuuriaukio': 0.04672843302137285,
#  'Kustaankartano': 0.04726905299949863,
#  'Kustaankatu': 0.06554612018072824,
#  'Kutsuntatie': 0.030216090811982343,
#  'Kuunkatu': 0.0305891140359862,
#  'Kuusitie': 0.06982471845978172,
#  'Kylävoudintie': 0.053059052506659654,
#  'Käpylän asema': 0.061726969123450694,
#  'Käpyläntie': 0.06217987937131987,
#  'Käskynhaltijantie': 0.042570981715523114,
#  'Laajalahden aukio': 0.07287473495722124,
#  'Laajalahden keskus': 0.058527119745430345,
#  'Laajasalon ostoskeskus': 0.03418981762786743,
#  'Laivalahden puistotie': 0.04488571309603128,
#  'Laivasillankatu': 0.05622109755687707,
#  'Lastenlehto': 0.06738071205096,
#  'Lauttasaaren ostoskeskus': 0.06713075375598378,
#  'Lauttasaarensilta': 0.06331668249233753,
#  'Lehtisaarentie': 0.06864984314101724,
#  'Lepolantie': 0.055831769726823785,
#  'Leppäsuonaukio': 0.06818122190025794,
#  'Leppävaaran uimahalli': 0.0294585393728127,
#  'Leppävaaran urheilupuisto': 0.03173393807035491,
#  'Leppävaaranaukio': 0.055187720337446,
#  'Leppävaarankäytävä': 0.052504176513668434,
#  'Liisanpuistikko': 0.0634922571800733,
#  'Linnakepolku': 0.03668572785498347,
#  'Linnanmäki': 0.06865685212218789,
#  'Linnuntie': 0.03391334551433984,
#  'Lintulahdenkatu': 0.06287667341569823,
#  'Louhentori': 0.040825637270952064,
#  'Lukutori': 0.026655641250933955,
#  'Lumivaarantie': 0.039366210531364264,
#  'Luoteisväylä': 0.0634799903060436,
#  'Lystimäensilta': 0.020216653490807385,
#  'Lystimäki': 0.02472218996779095,
#  'Läkkitori': 0.04520310416622578,
#  'Länsisatamankatu': 0.06720745261240257,
#  'Länsisatamankuja': 0.05960771365502003,
#  'Länsiterminaali': 0.05020313781772342,
#  'Länsituuli': 0.04828070434087173,
#  'Maarinranta': 0.041435160763168125,
#  'Maistraatintori': 0.06392483666414073,
#  'Majurinkulma': 0.05162589546758995,
#  'Mamsellimyllynkatu': 0.02468395034477036,
#  'Mankkaanaukio': 0.04094728448375627,
#  'Mankkaanlaaksontie': 0.03887458254806421,
#  'Mannerheimintie': 0.066438360210686,
#  'Margareetankuja': 0.03421160544468384,
#  'Marian sairaala': 0.06897464463698584,
#  'Marjaniementie': 0.02439033910218743,
#  'Marjaniemi': 0.017267097285059516,
#  'Marttila': 0.05142210411231491,
#  'Mastokatu': 0.05235540864833048,
#  'Matinkartanontie': 0.03138581755673495,
#  'Matinkyläntie': 0.023977948339532207,
#  'Matinlahdenranta': 0.02498917699604221,
#  'Maunula': 0.05476168363704234,
#  'Meilahden sairaala': 0.06930467745578933,
#  'Melkonkuja': 0.053508242364762267,
#  'Mellstenintie': 0.03819487729061601,
#  'Merihaka': 0.057809906697640495,
#  'Merisotilaantori': 0.05260493039114465,
#  'Messeniuksenkatu': 0.0701373848315016,
#  'Metsänneidonpolku': 0.0452617286402929,
#  'Munkkiniemen aukio': 0.0709118007265225,
#  'Muotoilijankatu': 0.05234449285356916,
#  'Mustikkamaa': 0.05257464536290697,
#  'Muurarinkuja': 0.035464977373645144,
#  'Muusantori': 0.06281017226340743,
#  'Myllypuro (M)': 0.030637112715826545,
#  'Mäkelänkatu': 0.06626049292843382,
#  'Mäkitorpantie': 0.04763540737896377,
#  'Mäkkylän asema': 0.04754997042926821,
#  'Mäntyviita': 0.050125842070853306,
#  'Narinkka': 0.07078434002917187,
#  'Nelikkotie': 0.028608569276935482,
#  'Niittykumpu (M)': 0.04550339219302601,
#  'Niittymaa': 0.04397488317746207,
#  'Nokkala': 0.03095920351725385,
#  'Nordenskiöldinaukio': 0.06915892362156688,
#  'Nuottaniementie': 0.02202725941840543,
#  'Näkinsilta': 0.0645338995552169,
#  'Näyttelijäntie': 0.055460323064638786,
#  'Olarinluoma': 0.030531481192777765,
#  'Olympiastadion': 0.06870240859880089,
#  'Ooppera': 0.06940965062738157,
#  'Opastinsilta': 0.06481505576556625,
#  'Oravannahkatori': 0.0379772851033088,
#  'Orionintie': 0.02176216547048838,
#  'Orpaanporras': 0.022463870579466624,
#  'Otaranta': 0.06501308189182661,
#  'Otsolahti': 0.05301625119201293,
#  'Otto Brandtin tie': 0.047891805501968074,
#  'Oulunkylän asema': 0.05480022900902378,
#  'Outotec': 0.01698906515548584,
#  'Paavalinpuisto': 0.06298424576310757,
#  'Paciuksenkaari': 0.07200478935441529,
#  'Paciuksenkatu': 0.06918798320740914,
#  'Painiitty': 0.03782356746158305,
#  'Pajamäki': 0.05650809758952323,
#  'Pasilan asema': 0.0672562458346018,
#  'Pernajantie': 0.06614105473523818,
#  'Perämiehenkatu': 0.06277806551339749,
#  'Petter Wetterin tie': 0.052110410040973124,
#  'Peukaloisentie': 0.029834440413374363,
#  'Pihlajamäki': 0.041528043236802384,
#  'Piispankallio': 0.028409128118838774,
#  'Piispanportti': 0.02822286364720797,
#  'Piispansilta': 0.04823071301181484,
#  'Pitäjänmäen asema': 0.05386231116146949,
#  'Pohjankulma': 0.04610504244728606,
#  'Pohjois-Haagan asema': 0.05417308205144343,
#  'Pohjolanaukio': 0.06020701754729544,
#  'Pohjolankatu': 0.05798022334134893,
#  'Porolahden koulu': 0.03719081224633811,
#  'Porthania': 0.06703405728365826,
#  'Postipuun koulu': 0.035079390283540186,
#  'Prinsessantie': 0.023642022631876095,
#  'Puistokaari': 0.06084466566481211,
#  'Puotila (M)': 0.024594066298534237,
#  'Puotilan ostoskeskus': 0.023181064588710932,
#  'Puotilantie': 0.020768224939330875,
#  'Puotinharju': 0.023137074841156857,
#  'Puotinkylän kartano': 0.01810130657392004,
#  'Päijänteentie': 0.06181595889046928,
#  'Radiokatu': 0.06430980849610027,
#  'Rajasaarentie': 0.06573329553532613,
#  'Ratapihantie': 0.06871989896976516,
#  'Ratsutori': 0.05144323247991018,
#  'Rautatieläisenkatu': 0.06854537311382505,
#  'Rautatientori / itä': 0.06997919677159668,
#  'Rautatientori / länsi': 0.07158458525693498,
#  'Reiherintie': 0.029934798894445714,
#  'Relanderinaukio': 0.05262406567150426,
#  'Revontulentie': 0.048837235237733576,
#  'Ritarikatu': 0.06002570162284701,
#  'Roihupelto': 0.03150514384801965,
#  'Rummunlyöjänkatu': 0.04184625178422188,
#  'Ruomelantie': 0.028374285992663225,
#  'Ruskeasuon varikko': 0.06274002892584733,
#  'Ruutikatu': 0.02603520942144046,
#  'Salmisaarenranta': 0.060309953953544125,
#  'Sammonpuistikko': 0.06526440650530443,
#  'Sateentie': 0.054653260166520834,
#  'Saunalahdentie': 0.06895394856064077,
#  'Senaatintori': 0.061720159896439496,
#  'Sepetlahdentie': 0.019616115554464957,
#  'Sepänkatu': 0.06557743904168181,
#  'Seurasaari': 0.06833011434627126,
#  'Siilitie (M)': 0.03950759636062263,
#  'Siilitie 13': 0.026538280329213477,
#  'Siilitie 9': 0.03452198372953196,
#  'Siltavoudintie': 0.048675664619213535,
#  'Sofianlehdonkatu': 0.057900678986386046,
#  'Stenbäckinkatu': 0.06780004330669594,
#  'Suomenlahdentie': 0.03935247376217812,
#  'Suurpellonaukio': 0.02547418148820859,
#  'Sähkömies': 0.05331809567101825,
#  'Säteri': 0.049766675836577394,
#  'Säterinniitty': 0.03757519794948991,
#  'Säterinrinne': 0.03508678742559244,
#  'Sörnäinen (M)': 0.06969991668955526,
#  'Takomotie': 0.06135088837078651,
#  'Tammisalon aukio': 0.03334249706088754,
#  'Tapiolan urheilupuisto': 0.03613491834011044,
#  'Tapionaukio': 0.054915738612755366,
#  'Tekniikantie': 0.05154639652030668,
#  'Teljäntie': 0.06533228597935976,
#  'Tenholantie': 0.0698733032347928,
#  'Teollisuuskatu': 0.06553498087562498,
#  'Teurastamo': 0.06415765652066875,
#  'Thalianaukio': 0.05911873148501803,
#  'Tietäjä': 0.041043066326069765,
#  'Tiistiläntie': 0.018112941129129697,
#  'Tiistinkallio': 0.022640642655789075,
#  'Tilkantori': 0.06739193259959923,
#  'Tilkanvierto': 0.07127178757414841,
#  'Toinen linja': 0.06562129804919195,
#  'Tontunmäentie': 0.026273655519285823,
#  'Toppelundinportti': 0.03301561136531324,
#  'Toppelundintie': 0.025897025673684074,
#  'Torpanranta': 0.06781649682845207,
#  'Tulisuontie': 0.030378047928686338,
#  'Tunnelitie': 0.06466367253344728,
#  'Tupasaarentie': 0.04483989551277893,
#  'Tuulimäki': 0.03525111556108328,
#  'Tyynenmerenkatu': 0.060155137491168256,
#  'Töölönkatu': 0.06644137628185195,
#  'Töölönlahden puisto': 0.06591996368571153,
#  'Töölönlahdenkatu': 0.07240395717725923,
#  'Töölöntori': 0.06723131317512816,
#  'Töölöntulli': 0.07138028991994255,
#  'Uimastadion': 0.06737894418594982,
#  'Ulvilantie': 0.06589243245877625,
#  'Unioninkatu': 0.06631736548914602,
#  'Upseerinkatu': 0.037515869266919535,
#  'Urheilupuisto (M)': 0.047823082326754356,
#  'Valimon asema': 0.05448773035359006,
#  'Valimotie': 0.06149597123485612,
#  'Vallikatu': 0.02874403726094046,
#  'Vallilan\xa0varikko': 0.056247810717391857,
#  'Vallipolku': 0.0331563277532897,
#  'Vanha Kauppahalli': 0.05508893346365074,
#  'Vanha Viertotie': 0.06288350127522907,
#  'Vanha kirkkopuisto': 0.06945647747652686,
#  'Varsapuistikko': 0.06543141445107631,
#  'Velodrominrinne': 0.06374593632092422,
#  'Venttiilikuja': 0.06761273696204705,
#  'Verkatehtaanpuisto': 0.06211164085321219,
#  'Vesakkotie': 0.055941353053430155,
#  'Vihdintie': 0.06814973435821937,
#  'Viikin normaalikoulu': 0.04461915143939767,
#  'Viikin tiedepuisto': 0.05291812153103715,
#  'Viiskulma': 0.06373807768786321,
#  'Vilhonvuorenkatu': 0.06349391986868178,
#  'Voikukantie': 0.029388757690314897,
#  'Von Daehnin katu': 0.030709944670886235,
#  'Westendinasema': 0.05050662427883408,
#  'Westendintie': 0.03906946174215959,
#  'Yhdyskunnankuja': 0.04081111520636181,
#  'Ympyrätalo': 0.0716977757035093}

# %%
sorted_eigenvector=sorted(eigenvector.items(),key=itemgetter(1),reverse=True)
sorted_eigenvector
# Out:
# [('Haukilahdenkatu', 0.07518513059120188),
#  ('Itämerentori', 0.07377579534470748),
#  ('Laajalahden aukio', 0.07287473495722124),
#  ('Kamppi (M)', 0.07251984669873815),
#  ('Töölönlahdenkatu', 0.07240395717725923),
#  ('Paciuksenkaari', 0.07200478935441529),
#  ('Huopalahdentie', 0.0719509082791253),
#  ('Ympyrätalo', 0.0716977757035093),
#  ('Rautatientori / länsi', 0.07158458525693498),
#  ('Töölöntulli', 0.07138028991994255),
#  ('Korjaamo', 0.07136156405311259),
#  ('Tilkanvierto', 0.07127178757414841),
#  ('Kaisaniemenpuisto', 0.0709494753888168),
#  ('Munkkiniemen aukio', 0.0709118007265225),
#  ('Narinkka', 0.07078434002917187),
#  ('Diakoniapuisto', 0.07045072293117978),
#  ('Baana', 0.0703772161520264),
#  ('Eteläinen Hesperiankatu', 0.07016493957170845),
#  ('Messeniuksenkatu', 0.0701373848315016),
#  ('Rautatientori / itä', 0.06997919677159668),
#  ('Tenholantie', 0.0698733032347928),
#  ('Kuusitie', 0.06982471845978172),
#  ('Sörnäinen (M)', 0.06969991668955526),
#  ('Vanha kirkkopuisto', 0.06945647747652686),
#  ('Ooppera', 0.06940965062738157),
#  ('Fleminginkatu', 0.06934003402155972),
#  ('Meilahden sairaala', 0.06930467745578933),
#  ('Paciuksenkatu', 0.06918798320740914),
#  ('Nordenskiöldinaukio', 0.06915892362156688),
#  ('Esterinportti', 0.06913853195912492),
#  ('Marian sairaala', 0.06897464463698584),
#  ('Saunalahdentie', 0.06895394856064077),
#  ('Apollonkatu', 0.0688388049015624),
#  ('Ratapihantie', 0.06871989896976516),
#  ('Hietalahdentori', 0.06870494152979886),
#  ('Olympiastadion', 0.06870240859880089),
#  ('Linnanmäki', 0.06865685212218789),
#  ('Lehtisaarentie', 0.06864984314101724),
#  ('Kesäkatu', 0.06860785571458859),
#  ('Rautatieläisenkatu', 0.06854537311382505),
#  ('Hertanmäenkatu', 0.06849823482788403),
#  ('Seurasaari', 0.06833011434627126),
#  ('Jätkäsaarenlaituri', 0.06825444399452196),
#  ('Leppäsuonaukio', 0.06818122190025794),
#  ('Vihdintie', 0.06814973435821937),
#  ('Kiasma', 0.06808820205922236),
#  ('Torpanranta', 0.06781649682845207),
#  ('Stenbäckinkatu', 0.06780004330669594),
#  ('Brahen kenttä', 0.06761852156438213),
#  ('Venttiilikuja', 0.06761273696204705),
#  ('Jalavatie', 0.06739924248102558),
#  ('Tilkantori', 0.06739193259959923),
#  ('Lastenlehto', 0.06738071205096),
#  ('Uimastadion', 0.06737894418594982),
#  ('Aalto-yliopisto (M), Korkeakouluaukio', 0.06733202017952142),
#  ('Pasilan asema', 0.0672562458346018),
#  ('Töölöntori', 0.06723131317512816),
#  ('Länsisatamankatu', 0.06720745261240257),
#  ('Eteläesplanadi', 0.06715926928123443),
#  ('Lauttasaaren ostoskeskus', 0.06713075375598378),
#  ('Porthania', 0.06703405728365826),
#  ('Haagan tori', 0.0668070882132391),
#  ('Elimäenkatu', 0.0667884006261144),
#  ('Töölönkatu', 0.06644137628185195),
#  ('Mannerheimintie', 0.066438360210686),
#  ('Unioninkatu', 0.06631736548914602),
#  ('Kanavaranta', 0.06631620142546028),
#  ('Mäkelänkatu', 0.06626049292843382),
#  ('Gebhardinaukio', 0.0662049218642019),
#  ('Jäähalli', 0.06616086296173969),
#  ('Hakaniemi (M)', 0.06614346269024605),
#  ('Pernajantie', 0.06614105473523818),
#  ('Koskelantie', 0.06599891139704013),
#  ('Töölönlahden puisto', 0.06591996368571153),
#  ('Ulvilantie', 0.06589243245877625),
#  ('Kiskontie', 0.06580230000134017),
#  ('Korppaanmäentie', 0.06578646335554308),
#  ('Rajasaarentie', 0.06573329553532613),
#  ('Toinen linja', 0.06562129804919195),
#  ('Kriikunakuja', 0.06560566760892855),
#  ('Sepänkatu', 0.06557743904168181),
#  ('Kustaankatu', 0.06554612018072824),
#  ('Teollisuuskatu', 0.06553498087562498),
#  ('Kalasatama (M)', 0.06549059780635988),
#  ('Varsapuistikko', 0.06543141445107631),
#  ('Teljäntie', 0.06533228597935976),
#  ('Sammonpuistikko', 0.06526440650530443),
#  ('Arabian kauppakeskus', 0.06522257062240719),
#  ('Brahen puistikko', 0.06517202733966243),
#  ('Hietaniemenkatu', 0.06512140647639118),
#  ('Otaranta', 0.06501308189182661),
#  ('Kalevankatu', 0.06496210981908684),
#  ('Opastinsilta', 0.06481505576556625),
#  ('Tunnelitie', 0.06466367253344728),
#  ('Karhupuisto', 0.06459748214882034),
#  ('Näkinsilta', 0.0645338995552169),
#  ('Kaivopuisto', 0.06445952579301008),
#  ('Radiokatu', 0.06430980849610027),
#  ('Arabiankatu', 0.06426006426877105),
#  ('Teurastamo', 0.06415765652066875),
#  ('Jämeräntaival', 0.06394938976143735),
#  ('Kauppakorkeakoulu', 0.06393882308505969),
#  ('Maistraatintori', 0.06392483666414073),
#  ('Velodrominrinne', 0.06374593632092422),
#  ('Viiskulma', 0.06373807768786321),
#  ('Hollolantie', 0.06367559355042138),
#  ('Gyldenintie', 0.06356250288456976),
#  ('Vilhonvuorenkatu', 0.06349391986868178),
#  ('Liisanpuistikko', 0.0634922571800733),
#  ('Albertinkatu', 0.06348755867114209),
#  ('Luoteisväylä', 0.0634799903060436),
#  ('Lauttasaarensilta', 0.06331668249233753),
#  ('Annankatu', 0.0631231151147187),
#  ('Intiankatu', 0.06309556157513486),
#  ('Isoisänsilta', 0.06307985450050983),
#  ('Haapaniemenkatu', 0.06303713794188333),
#  ('Paavalinpuisto', 0.06298424576310757),
#  ('Vanha Viertotie', 0.06288350127522907),
#  ('Lintulahdenkatu', 0.06287667341569823),
#  ('Muusantori', 0.06281017226340743),
#  ('Perämiehenkatu', 0.06277806551339749),
#  ('Ruskeasuon varikko', 0.06274002892584733),
#  ('Kapteeninpuistikko', 0.06266910463936479),
#  ('Huopalahden asema', 0.06244584037623229),
#  ('Kansallismuseo', 0.06235576870735433),
#  ('Käpyläntie', 0.06217987937131987),
#  ('Verkatehtaanpuisto', 0.06211164085321219),
#  ('Keilaranta', 0.062086983338317484),
#  ('Keilaniemi (M)', 0.062034740330332024),
#  ('Päijänteentie', 0.06181595889046928),
#  ('Käpylän asema', 0.061726969123450694),
#  ('Senaatintori', 0.061720159896439496),
#  ('Valimotie', 0.06149597123485612),
#  ('Heikkilänaukio', 0.06138554786655396),
#  ('Takomotie', 0.06135088837078651),
#  ('Keilalahti', 0.06132443493023254),
#  ('Erottajan aukio', 0.06122749683065773),
#  ('Heikkiläntie', 0.060872102931950584),
#  ('Puistokaari', 0.06084466566481211),
#  ('Arielinkatu', 0.06053886048451629),
#  ('Eläinmuseo', 0.06053368913873151),
#  ('Salmisaarenranta', 0.060309953953544125),
#  ('Pohjolanaukio', 0.06020701754729544),
#  ('Ilmalan asema', 0.06016878342567609),
#  ('Cygnaeuksenkatu', 0.06015842814895531),
#  ('Tyynenmerenkatu', 0.060155137491168256),
#  ('Kuikkarinne', 0.06003481100685547),
#  ('Ritarikatu', 0.06002570162284701),
#  ('Hernesaarenranta', 0.059759656008819474),
#  ('Länsisatamankuja', 0.05960771365502003),
#  ('Eerikinkatu', 0.059606141395510605),
#  ('Thalianaukio', 0.05911873148501803),
#  ('Laajalahden keskus', 0.058527119745430345),
#  ('Pohjolankatu', 0.05798022334134893),
#  ('Designmuseo', 0.05797588352209271),
#  ('Sofianlehdonkatu', 0.057900678986386046),
#  ('Merihaka', 0.057809906697640495),
#  ('Huovitie', 0.05773975141874103),
#  ('Itälahdenkatu', 0.0572269971964048),
#  ('Kasarmitori', 0.05688944633973931),
#  ('A.I. Virtasen aukio', 0.05672856486146217),
#  ('Pajamäki', 0.05650809758952323),
#  ('Aalto-yliopisto (M), Tietotie', 0.05628619889990218),
#  ('Kulosaari (M)', 0.0562663215644168),
#  ('Vallilan\xa0varikko', 0.056247810717391857),
#  ('Laivasillankatu', 0.05622109755687707),
#  ('Katariina Saksilaisen katu', 0.05610099288278749),
#  ('Juhana Herttuan tie', 0.056017610439563596),
#  ('Vesakkotie', 0.055941353053430155),
#  ('Lepolantie', 0.055831769726823785),
#  ('Kaapelitehdas', 0.055470839910981236),
#  ('Näyttelijäntie', 0.055460323064638786),
#  ('Gallen-Kallelan tie', 0.05542898123260999),
#  ('Ehrenströmintie', 0.05534864234977581),
#  ('Leppävaaranaukio', 0.055187720337446),
#  ('Vanha Kauppahalli', 0.05508893346365074),
#  ('Tapionaukio', 0.054915738612755366),
#  ('Oulunkylän asema', 0.05480022900902378),
#  ('Maunula', 0.05476168363704234),
#  ('Sateentie', 0.054653260166520834),
#  ('Valimon asema', 0.05448773035359006),
#  ('Pohjois-Haagan asema', 0.05417308205144343),
#  ('Betonimies', 0.053888497422833886),
#  ('Pitäjänmäen asema', 0.05386231116146949),
#  ('Jännetie', 0.05377653919127387),
#  ('Hämeenlinnanväylä', 0.05376702582846494),
#  ('Melkonkuja', 0.053508242364762267),
#  ('Sähkömies', 0.05331809567101825),
#  ('Kylävoudintie', 0.053059052506659654),
#  ('Otsolahti', 0.05301625119201293),
#  ('Viikin tiedepuisto', 0.05291812153103715),
#  ('Relanderinaukio', 0.05262406567150426),
#  ('Merisotilaantori', 0.05260493039114465),
#  ('Mustikkamaa', 0.05257464536290697),
#  ('Leppävaarankäytävä', 0.052504176513668434),
#  ('Mastokatu', 0.05235540864833048),
#  ('Muotoilijankatu', 0.05234449285356916),
#  ('Herttoniemi (M)', 0.0522488480923368),
#  ('Petter Wetterin tie', 0.052110410040973124),
#  ('Majurinkulma', 0.05162589546758995),
#  ('Tekniikantie', 0.05154639652030668),
#  ('Ratsutori', 0.05144323247991018),
#  ('Marttila', 0.05142210411231491),
#  ('Kirjurinkuja', 0.05136210623509907),
#  ('Hanasaari', 0.051108773650122216),
#  ('Koskelan varikko', 0.05109854406736939),
#  ('Westendinasema', 0.05050662427883408),
#  ('Länsiterminaali', 0.05020313781772342),
#  ('Mäntyviita', 0.050125842070853306),
#  ('Säteri', 0.049766675836577394),
#  ('Ida Aalbergin tie', 0.049190311704604105),
#  ('Revontulentie', 0.048837235237733576),
#  ('Siltavoudintie', 0.048675664619213535),
#  ('Länsituuli', 0.04828070434087173),
#  ('Piispansilta', 0.04823071301181484),
#  ('Hernepellontie', 0.047920955319093635),
#  ('Otto Brandtin tie', 0.047891805501968074),
#  ('Urheilupuisto (M)', 0.047823082326754356),
#  ('Mäkitorpantie', 0.04763540737896377),
#  ('Mäkkylän asema', 0.04754997042926821),
#  ('Kustaankartano', 0.04726905299949863),
#  ('Herttoniemenranta', 0.04697502516722144),
#  ('Kulttuuriaukio', 0.04672843302137285),
#  ('Pohjankulma', 0.04610504244728606),
#  ('Kalevalantie', 0.046039751930234706),
#  ('Niittykumpu (M)', 0.04550339219302601),
#  ('Metsänneidonpolku', 0.0452617286402929),
#  ('Läkkitori', 0.04520310416622578),
#  ('Laivalahden puistotie', 0.04488571309603128),
#  ('Korkeasaari', 0.04488446512474505),
#  ('Tupasaarentie', 0.04483989551277893),
#  ('Kirkkoherrantie', 0.04472424634088174),
#  ('Viikin normaalikoulu', 0.04461915143939767),
#  ('Kalkkipellonmäki', 0.04442768219908412),
#  ('Niittymaa', 0.04397488317746207),
#  ('Hakalehto', 0.043725127661111154),
#  ('Innopoli', 0.04312974983707692),
#  ('Herttoniemen kirkko', 0.042694369551033166),
#  ('Eränkävijäntori', 0.042642459997965766),
#  ('Käskynhaltijantie', 0.042570981715523114),
#  ('Aulangontie', 0.04197762557053689),
#  ('Rummunlyöjänkatu', 0.04184625178422188),
#  ('Pihlajamäki', 0.041528043236802384),
#  ('Maarinranta', 0.041435160763168125),
#  ('Abraham Wetterin tie', 0.04139558392731589),
#  ('Ahertajantie', 0.04132240063038489),
#  ('Asentajanpuisto', 0.04115859548348916),
#  ('Tietäjä', 0.041043066326069765),
#  ('Mankkaanaukio', 0.04094728448375627),
#  ('Louhentori', 0.040825637270952064),
#  ('Yhdyskunnankuja', 0.04081111520636181),
#  ('Siilitie (M)', 0.03950759636062263),
#  ('Agronominkatu', 0.03946546163613187),
#  ('Lumivaarantie', 0.039366210531364264),
#  ('Suomenlahdentie', 0.03935247376217812),
#  ('Agnetankuja', 0.039227114567288425),
#  ('Westendintie', 0.03906946174215959),
#  ('Mankkaanlaaksontie', 0.03887458254806421),
#  ('Mellstenintie', 0.03819487729061601),
#  ('Oravannahkatori', 0.0379772851033088),
#  ('Painiitty', 0.03782356746158305),
#  ('Säterinniitty', 0.03757519794948991),
#  ('Upseerinkatu', 0.037515869266919535),
#  ('Itäkeskus (M)', 0.037442551823260915),
#  ('Etuniementie', 0.037321602998510124),
#  ('Porolahden koulu', 0.03719081224633811),
#  ('Golfpolku', 0.036783169747063735),
#  ('Linnakepolku', 0.03668572785498347),
#  ('Tapiolan urheilupuisto', 0.03613491834011044),
#  ('Muurarinkuja', 0.035464977373645144),
#  ('Tuulimäki', 0.03525111556108328),
#  ('Säterinrinne', 0.03508678742559244),
#  ('Postipuun koulu', 0.035079390283540186),
#  ('Siilitie 9', 0.03452198372953196),
#  ('Hagalundinpuisto', 0.034507501533756174),
#  ('Margareetankuja', 0.03421160544468384),
#  ('Laajasalon ostoskeskus', 0.03418981762786743),
#  ('Komentajankatu', 0.03391736017073703),
#  ('Linnuntie', 0.03391334551433984),
#  ('Haukilahdenaukio', 0.03367478335069723),
#  ('Tammisalon aukio', 0.03334249706088754),
#  ('Vallipolku', 0.0331563277532897),
#  ('Toppelundinportti', 0.03301561136531324),
#  ('Isosaarentie', 0.032879434738896963),
#  ('Haukilahdenranta', 0.03214032386742077),
#  ('Leppävaaran urheilupuisto', 0.03173393807035491),
#  ('Roihupelto', 0.03150514384801965),
#  ('Matinkartanontie', 0.03138581755673495),
#  ('Nokkala', 0.03095920351725385),
#  ('Von Daehnin katu', 0.030709944670886235),
#  ('Myllypuro (M)', 0.030637112715826545),
#  ('Kuunkatu', 0.0305891140359862),
#  ('Auringonkatu', 0.030566287870987394),
#  ('Olarinluoma', 0.030531481192777765),
#  ('Tulisuontie', 0.030378047928686338),
#  ('Kutsuntatie', 0.030216090811982343),
#  ('Reiherintie', 0.029934798894445714),
#  ('Peukaloisentie', 0.029834440413374363),
#  ('Elfvik', 0.02951524336988557),
#  ('Leppävaaran uimahalli', 0.0294585393728127),
#  ('Voikukantie', 0.029388757690314897),
#  ('Koivu-Mankkaa', 0.02909961665915719),
#  ('Vallikatu', 0.02874403726094046),
#  ('Nelikkotie', 0.028608569276935482),
#  ('Piispankallio', 0.028409128118838774),
#  ('Ruomelantie', 0.028374285992663225),
#  ('Piispanportti', 0.02822286364720797),
#  ('Humalniementie', 0.02785350270568306),
#  ('Hauenkalliontie', 0.02686306734638715),
#  ('Lukutori', 0.026655641250933955),
#  ('Siilitie 13', 0.026538280329213477),
#  ('Friisilänaukio', 0.026463518178272773),
#  ('Tontunmäentie', 0.026273655519285823),
#  ('Ruutikatu', 0.02603520942144046),
#  ('Gransinmäki', 0.026019853831694945),
#  ('Toppelundintie', 0.025897025673684074),
#  ('Gunillantie', 0.025545779045645613),
#  ('Suurpellonaukio', 0.02547418148820859),
#  ('Komeetankatu', 0.025345204312565),
#  ('Matinlahdenranta', 0.02498917699604221),
#  ('Lystimäki', 0.02472218996779095),
#  ('Mamsellimyllynkatu', 0.02468395034477036),
#  ('Puotila (M)', 0.024594066298534237),
#  ('Marjaniementie', 0.02439033910218743),
#  ('Matinkyläntie', 0.023977948339532207),
#  ('Prinsessantie', 0.023642022631876095),
#  ('Hauenkallio', 0.023535770539478716),
#  ('Itäportti', 0.023382366615313725),
#  ('Puotilan ostoskeskus', 0.023181064588710932),
#  ('Puotinharju', 0.023137074841156857),
#  ('Tiistinkallio', 0.022640642655789075),
#  ('Karhulantie', 0.022464282478828267),
#  ('Orpaanporras', 0.022463870579466624),
#  ('Nuottaniementie', 0.02202725941840543),
#  ('Orionintie', 0.02176216547048838),
#  ('Puotilantie', 0.020768224939330875),
#  ('Lystimäensilta', 0.020216653490807385),
#  ('Alakiventie', 0.020029676553132033),
#  ('Sepetlahdentie', 0.019616115554464957),
#  ('Avaruuskatu', 0.01942739868394113),
#  ('Tiistiläntie', 0.018112941129129697),
#  ('Puotinkylän kartano', 0.01810130657392004),
#  ('Derby Business Park', 0.01789445723094259),
#  ('Marjaniemi', 0.017267097285059516),
#  ('Outotec', 0.01698906515548584),
#  ('Haakoninlahdenkatu', 0.016310849277556872),
#  ('Itäkeskus Metrovarikko', 0.014240220929167031)]

# %%
for t in sorted_eigenvector[:5]:
        print(t)
# Out:
# ('Haukilahdenkatu', 0.07518513059120188)
# ('Itämerentori', 0.07377579534470748)
# ('Laajalahden aukio', 0.07287473495722124)
# ('Kamppi (M)', 0.07251984669873815)
# ('Töölönlahdenkatu', 0.07240395717725923)

# %%
t7=sorted([d for n,d in sorted_eigenvector],reverse=True)
degreeCount = collections.Counter(t7)
deg, cnt = zip(*degreeCount.items())

# %%
fig,ax=plt.subplots(figsize=(15,7))

plt.scatter(deg,cnt,color='blue')

# %% [markdown]
# Conclusion:
# Haukilahdenkatu has highest eigenvector centrality. This means Haukilahdenkatu is the most important station as it's neighbours are those who themselves are connected to many other stations. Itamerentori and Laajalahden aukio are also important stations.

# %% [markdown]
# Pagerank Centrality

# %%
pagerank=nx.pagerank(G)
pagerank
# Out:
# {'A.I. Virtasen aukio': 0.0029364306240015673,
#  'Aalto-yliopisto (M), Korkeakouluaukio': 0.003769177733021174,
#  'Aalto-yliopisto (M), Tietotie': 0.003243304916659689,
#  'Abraham Wetterin tie': 0.002450546070724548,
#  'Agnetankuja': 0.0023305479274433405,
#  'Agronominkatu': 0.002383486069748388,
#  'Ahertajantie': 0.0026582850218117085,
#  'Alakiventie': 0.0016143081086448057,
#  'Albertinkatu': 0.0032922641091317605,
#  'Annankatu': 0.0032807234451251452,
#  'Apollonkatu': 0.0035836378237926784,
#  'Arabian kauppakeskus': 0.0034932973596494723,
#  'Arabiankatu': 0.003414043371464274,
#  'Arielinkatu': 0.00324348080149646,
#  'Asentajanpuisto': 0.00243931377094286,
#  'Aulangontie': 0.0024214315509069498,
#  'Auringonkatu': 0.0021155491561996452,
#  'Avaruuskatu': 0.0016601012211478812,
#  'Baana': 0.0038017562656958424,
#  'Betonimies': 0.0030245205232787486,
#  'Brahen kenttä': 0.0035908666836442405,
#  'Brahen puistikko': 0.003433560318759679,
#  'Cygnaeuksenkatu': 0.0030392678137698094,
#  'Derby Business Park': 0.0013134723836778182,
#  'Designmuseo': 0.0029370874374425532,
#  'Diakoniapuisto': 0.003753881160334786,
#  'Eerikinkatu': 0.0030642898185722217,
#  'Ehrenströmintie': 0.002822144018886397,
#  'Elfvik': 0.0019326221061778499,
#  'Elimäenkatu': 0.003543897339753757,
#  'Eläinmuseo': 0.00306435622868397,
#  'Erottajan aukio': 0.003173197240504155,
#  'Eränkävijäntori': 0.002508345809262693,
#  'Esterinportti': 0.003671552216988659,
#  'Eteläesplanadi': 0.003581296783929918,
#  'Eteläinen Hesperiankatu': 0.0037140844551127815,
#  'Etuniementie': 0.0023339916923363034,
#  'Fleminginkatu': 0.003744783385330602,
#  'Friisilänaukio': 0.0019578102992072405,
#  'Gallen-Kallelan tie': 0.0029895638566964323,
#  'Gebhardinaukio': 0.00352145507863747,
#  'Golfpolku': 0.0023788613295979417,
#  'Gransinmäki': 0.0017957679798319471,
#  'Gunillantie': 0.001747527837798963,
#  'Gyldenintie': 0.0034520815679557624,
#  'Haagan tori': 0.0035084660013171387,
#  'Haakoninlahdenkatu': 0.001353251327052279,
#  'Haapaniemenkatu': 0.003311971731424127,
#  'Hagalundinpuisto': 0.0021820980494181887,
#  'Hakalehto': 0.0026777780508249055,
#  'Hakaniemi (M)': 0.003554312167362268,
#  'Hanasaari': 0.0029985744427163466,
#  'Hauenkallio': 0.0018175001482259876,
#  'Hauenkalliontie': 0.0019403233969387582,
#  'Haukilahdenaukio': 0.0022684596293787514,
#  'Haukilahdenkatu': 0.00431965900734245,
#  'Haukilahdenranta': 0.0021698606846212907,
#  'Heikkilänaukio': 0.003271228208682197,
#  'Heikkiläntie': 0.0031750539535178586,
#  'Hernepellontie': 0.002646245866964501,
#  'Hernesaarenranta': 0.0031011969011560544,
#  'Hertanmäenkatu': 0.0036061164514923404,
#  'Herttoniemen kirkko': 0.0025082494859329546,
#  'Herttoniemenranta': 0.0026642099854850424,
#  'Herttoniemi (M)': 0.0029074868408380597,
#  'Hietalahdentori': 0.0036614589512050525,
#  'Hietaniemenkatu': 0.003341370598222792,
#  'Hollolantie': 0.003318744545890926,
#  'Humalniementie': 0.0018668900495875142,
#  'Huopalahden asema': 0.0032435316055745215,
#  'Huopalahdentie': 0.0038823920721154153,
#  'Huovitie': 0.00292203195804388,
#  'Hämeenlinnanväylä': 0.0027648856082187413,
#  'Ida Aalbergin tie': 0.0025862647996465708,
#  'Ilmalan asema': 0.0030941561068474903,
#  'Innopoli': 0.0026641180141366654,
#  'Intiankatu': 0.0032980990532531485,
#  'Isoisänsilta': 0.003404907664636172,
#  'Isosaarentie': 0.0020843602946578645,
#  'Itäkeskus (M)': 0.002319963847095612,
#  'Itäkeskus Metrovarikko': 0.0013186521811749436,
#  'Itälahdenkatu': 0.0030484596037634168,
#  'Itämerentori': 0.00412750452519659,
#  'Itäportti': 0.001846357830693902,
#  'Jalavatie': 0.0034884451159723565,
#  'Juhana Herttuan tie': 0.002976096551594403,
#  'Jämeräntaival': 0.0036198094405105307,
#  'Jännetie': 0.0028799039860847855,
#  'Jätkäsaarenlaituri': 0.0036243433265188037,
#  'Jäähalli': 0.003430542843175286,
#  'Kaapelitehdas': 0.002821946111923915,
#  'Kaisaniemenpuisto': 0.003897151930804098,
#  'Kaivopuisto': 0.0034385564127807546,
#  'Kalasatama (M)': 0.0035651201811866292,
#  'Kalevalantie': 0.0028244931963117064,
#  'Kalevankatu': 0.003402505956955787,
#  'Kalkkipellonmäki': 0.0025035575975228866,
#  'Kamppi (M)': 0.003964559022112063,
#  'Kanavaranta': 0.0035643559989106447,
#  'Kansallismuseo': 0.003173123758516657,
#  'Kapteeninpuistikko': 0.00328842783940281,
#  'Karhulantie': 0.0016618025189943314,
#  'Karhupuisto': 0.0033189114219887767,
#  'Kasarmitori': 0.002890639763935359,
#  'Katariina Saksilaisen katu': 0.0030204657208476524,
#  'Kauppakorkeakoulu': 0.003269252481056516,
#  'Keilalahti': 0.0034332589884848263,
#  'Keilaniemi (M)': 0.0034969376686466505,
#  'Keilaranta': 0.0034807016870505897,
#  'Kesäkatu': 0.003602473767484768,
#  'Kiasma': 0.0035657210000324996,
#  'Kirjurinkuja': 0.0028625103008741333,
#  'Kirkkoherrantie': 0.00237846320310361,
#  'Kiskontie': 0.003375153844683216,
#  'Koivu-Mankkaa': 0.002172658339175239,
#  'Komeetankatu': 0.0019387108621665085,
#  'Komentajankatu': 0.0020863590875429406,
#  'Korjaamo': 0.00381675984666356,
#  'Korkeasaari': 0.0024227045291895363,
#  'Korppaanmäentie': 0.003389799955839922,
#  'Koskelan varikko': 0.002711929919820962,
#  'Koskelantie': 0.0034946021180295734,
#  'Kriikunakuja': 0.003392556579488789,
#  'Kuikkarinne': 0.003229453952256805,
#  'Kulosaari (M)': 0.003065834641158331,
#  'Kulttuuriaukio': 0.002872757954590653,
#  'Kustaankartano': 0.0025219866203280033,
#  'Kustaankatu': 0.0034699768312359556,
#  'Kutsuntatie': 0.001894830785159501,
#  'Kuunkatu': 0.002170221887841359,
#  'Kuusitie': 0.003688881808993938,
#  'Kylävoudintie': 0.002793277552915321,
#  'Käpylän asema': 0.0032246271497456706,
#  'Käpyläntie': 0.003265436709416852,
#  'Käskynhaltijantie': 0.0023302527946090852,
#  'Laajalahden aukio': 0.004003204459193389,
#  'Laajalahden keskus': 0.0033351581902936024,
#  'Laajasalon ostoskeskus': 0.002128901730676243,
#  'Laivalahden puistotie': 0.0025727183272200617,
#  'Laivasillankatu': 0.0028840402281752214,
#  'Lastenlehto': 0.003562075625570916,
#  'Lauttasaaren ostoskeskus': 0.00366995243957641,
#  'Lauttasaarensilta': 0.0034396300350987338,
#  'Lehtisaarentie': 0.0037491357921800926,
#  'Lepolantie': 0.002917273904472884,
#  'Leppäsuonaukio': 0.003595868826553138,
#  'Leppävaaran uimahalli': 0.0019573508701847984,
#  'Leppävaaran urheilupuisto': 0.0020777876309238303,
#  'Leppävaaranaukio': 0.0031644168565415067,
#  'Leppävaarankäytävä': 0.00296275057925434,
#  'Liisanpuistikko': 0.0033365644689836303,
#  'Linnakepolku': 0.002364764225968234,
#  'Linnanmäki': 0.0036323531547844006,
#  'Linnuntie': 0.0021115557619858787,
#  'Lintulahdenkatu': 0.0033783858117051985,
#  'Louhentori': 0.002635692325800544,
#  'Lukutori': 0.002024298879768358,
#  'Lumivaarantie': 0.0025024806868259417,
#  'Luoteisväylä': 0.0034957479258567775,
#  'Lystimäensilta': 0.00170625938182657,
#  'Lystimäki': 0.0019173897985714325,
#  'Läkkitori': 0.0026255715534944653,
#  'Länsisatamankatu': 0.0036102782972864725,
#  'Länsisatamankuja': 0.0030156828477101547,
#  'Länsiterminaali': 0.002479239136308629,
#  'Länsituuli': 0.0028878181044359945,
#  'Maarinranta': 0.0026272789998376743,
#  'Maistraatintori': 0.003267854674953261,
#  'Majurinkulma': 0.002874332760284057,
#  'Mamsellimyllynkatu': 0.0017650114035462053,
#  'Mankkaanaukio': 0.0026483011905366538,
#  'Mankkaanlaaksontie': 0.0025835924802909893,
#  'Mannerheimintie': 0.003471369745676589,
#  'Margareetankuja': 0.0021415371917046905,
#  'Marian sairaala': 0.0037023396510610417,
#  'Marjaniementie': 0.0017579622672124814,
#  'Marjaniemi': 0.0014587031130526666,
#  'Marttila': 0.0027338550923925167,
#  'Mastokatu': 0.0026399631057273435,
#  'Matinkartanontie': 0.0021649699372825798,
#  'Matinkyläntie': 0.0018127755743282063,
#  'Matinlahdenranta': 0.0018593298854631647,
#  'Maunula': 0.002825411901206651,
#  'Meilahden sairaala': 0.003636258104342151,
#  'Melkonkuja': 0.002788531187567336,
#  'Mellstenintie': 0.002420314344770089,
#  'Merihaka': 0.003056729064737123,
#  'Merisotilaantori': 0.0026369504865065324,
#  'Messeniuksenkatu': 0.003730935886825378,
#  'Metsänneidonpolku': 0.00280231426885365,
#  'Munkkiniemen aukio': 0.003822221537375289,
#  'Muotoilijankatu': 0.00277117937326244,
#  'Mustikkamaa': 0.0028912300159840165,
#  'Muurarinkuja': 0.00218267626151864,
#  'Muusantori': 0.0032959180255385193,
#  'Myllypuro (M)': 0.002043687471045781,
#  'Mäkelänkatu': 0.0035799332147618775,
#  'Mäkitorpantie': 0.002547590766236892,
#  'Mäkkylän asema': 0.0026434905413400345,
#  'Mäntyviita': 0.0029803159038891587,
#  'Narinkka': 0.003860735355514737,
#  'Nelikkotie': 0.0020632721334453816,
#  'Niittykumpu (M)': 0.002802390366203418,
#  'Niittymaa': 0.002759721954224843,
#  'Nokkala': 0.002097624298149751,
#  'Nordenskiöldinaukio': 0.003640007326909361,
#  'Nuottaniementie': 0.0017339167137691183,
#  'Näkinsilta': 0.003474286798695986,
#  'Näyttelijäntie': 0.0029469046428598385,
#  'Olarinluoma': 0.0022554395050624226,
#  'Olympiastadion': 0.0036013338572494723,
#  'Ooppera': 0.0036666541864604574,
#  'Opastinsilta': 0.003361100087302381,
#  'Oravannahkatori': 0.002464916492616549,
#  'Orionintie': 0.0017326050271412638,
#  'Orpaanporras': 0.0016882881625633422,
#  'Otaranta': 0.0036215794235259025,
#  'Otsolahti': 0.003108120396519279,
#  'Otto Brandtin tie': 0.002662004180612847,
#  'Oulunkylän asema': 0.002930978743897136,
#  'Outotec': 0.0015278039813173161,
#  'Paavalinpuisto': 0.003314109347064626,
#  'Paciuksenkaari': 0.003895174227627984,
#  'Paciuksenkatu': 0.0036685687779151837,
#  'Painiitty': 0.0022305827083263746,
#  'Pajamäki': 0.0029940571979486966,
#  'Pasilan asema': 0.0035056239906237022,
#  'Pernajantie': 0.0035402900642026954,
#  'Perämiehenkatu': 0.0032986992028421398,
#  'Petter Wetterin tie': 0.0028815470542246317,
#  'Peukaloisentie': 0.001972928114609401,
#  'Pihlajamäki': 0.0024428965123461867,
#  'Piispankallio': 0.002049900199410091,
#  'Piispanportti': 0.0020379623103409105,
#  'Piispansilta': 0.0028728314158514034,
#  'Pitäjänmäen asema': 0.00284986772580795,
#  'Pohjankulma': 0.0028363646825611826,
#  'Pohjois-Haagan asema': 0.0029032216997081253,
#  'Pohjolanaukio': 0.003141370644082445,
#  'Pohjolankatu': 0.0029493568093023705,
#  'Porolahden koulu': 0.0022516844736937733,
#  'Porthania': 0.0035238123668830785,
#  'Postipuun koulu': 0.0021186252031629633,
#  'Prinsessantie': 0.0017236967453728223,
#  'Puistokaari': 0.0033680858082941263,
#  'Puotila (M)': 0.001769860054713542,
#  'Puotilan ostoskeskus': 0.0016978500711640964,
#  'Puotilantie': 0.0016236934488247363,
#  'Puotinharju': 0.0017261045211837583,
#  'Puotinkylän kartano': 0.0014945719047851985,
#  'Päijänteentie': 0.003268298790906858,
#  'Radiokatu': 0.0032776130797009875,
#  'Rajasaarentie': 0.003435461271278347,
#  'Ratapihantie': 0.0036449992013044222,
#  'Ratsutori': 0.002961235259219523,
#  'Rautatieläisenkatu': 0.0036483029910159078,
#  'Rautatientori / itä': 0.003794483668456338,
#  'Rautatientori / länsi': 0.0038731303796092896,
#  'Reiherintie': 0.001943506581897503,
#  'Relanderinaukio': 0.0028921130082546495,
#  'Revontulentie': 0.002895244033422838,
#  'Ritarikatu': 0.0030860170215482397,
#  'Roihupelto': 0.0020673953295458555,
#  'Rummunlyöjänkatu': 0.002606227783154052,
#  'Ruomelantie': 0.0020651773940605768,
#  'Ruskeasuon varikko': 0.0031952830994050863,
#  'Ruutikatu': 0.001754335393583602,
#  'Salmisaarenranta': 0.0031093778648836846,
#  'Sammonpuistikko': 0.0033549933327897243,
#  'Sateentie': 0.003176400002015234,
#  'Saunalahdentie': 0.0037152364779942755,
#  'Senaatintori': 0.003225312240133375,
#  'Sepetlahdentie': 0.00164444355170336,
#  'Sepänkatu': 0.003483238621242362,
#  'Seurasaari': 0.0036057884927348676,
#  'Siilitie (M)': 0.002383900000419379,
#  'Siilitie 13': 0.0018627272928772134,
#  'Siilitie 9': 0.0022072894931197797,
#  'Siltavoudintie': 0.002592979228796066,
#  'Sofianlehdonkatu': 0.0029504239173741517,
#  'Stenbäckinkatu': 0.003511285380649128,
#  'Suomenlahdentie': 0.002524810451660697,
#  'Suurpellonaukio': 0.0019517221769447906,
#  'Sähkömies': 0.0031014296593512287,
#  'Säteri': 0.0028502925587314785,
#  'Säterinniitty': 0.0024060249093547687,
#  'Säterinrinne': 0.002260167925050481,
#  'Sörnäinen (M)': 0.0037864038725811764,
#  'Takomotie': 0.003209864051292789,
#  'Tammisalon aukio': 0.002094564085407738,
#  'Tapiolan urheilupuisto': 0.002427205646190353,
#  'Tapionaukio': 0.003186980977370591,
#  'Tekniikantie': 0.003052002247328695,
#  'Teljäntie': 0.00345666682270758,
#  'Tenholantie': 0.003673027981913896,
#  'Teollisuuskatu': 0.0034590266297011597,
#  'Teurastamo': 0.003448400765722087,
#  'Thalianaukio': 0.0030785862252098437,
#  'Tietäjä': 0.0026299991763421757,
#  'Tiistiläntie': 0.0015876074949066862,
#  'Tiistinkallio': 0.0017556694769523843,
#  'Tilkantori': 0.0035142743940130157,
#  'Tilkanvierto': 0.0038015449836469087,
#  'Toinen linja': 0.0033924651612768472,
#  'Tontunmäentie': 0.0020011748445802383,
#  'Toppelundinportti': 0.0022044664701989665,
#  'Toppelundintie': 0.0019209167209296705,
#  'Torpanranta': 0.003625920970692453,
#  'Tulisuontie': 0.00199609686598154,
#  'Tunnelitie': 0.003345206102900903,
#  'Tupasaarentie': 0.00255971112447564,
#  'Tuulimäki': 0.0023080752572243804,
#  'Tyynenmerenkatu': 0.0031144997519330707,
#  'Töölönkatu': 0.0034264239950827628,
#  'Töölönlahden puisto': 0.003403495883552499,
#  'Töölönlahdenkatu': 0.003938348877990376,
#  'Töölöntori': 0.003534650744928585,
#  'Töölöntulli': 0.003814995756879654,
#  'Uimastadion': 0.003532077273247341,
#  'Ulvilantie': 0.0034320066667312635,
#  'Unioninkatu': 0.003532393043426784,
#  'Upseerinkatu': 0.0022772657654097335,
#  'Urheilupuisto (M)': 0.0029183737403161696,
#  'Valimon asema': 0.0028413142065689123,
#  'Valimotie': 0.0032273226939009475,
#  'Vallikatu': 0.001881697261020505,
#  'Vallilan\xa0varikko': 0.002895646664355951,
#  'Vallipolku': 0.002048773183811409,
#  'Vanha Kauppahalli': 0.0028561330484065625,
#  'Vanha Viertotie': 0.003252299499533454,
#  'Vanha kirkkopuisto': 0.0037406043530249854,
#  'Varsapuistikko': 0.0034584917137027936,
#  'Velodrominrinne': 0.0033011444720768427,
#  'Venttiilikuja': 0.0035458154699896834,
#  'Verkatehtaanpuisto': 0.0033267012924188643,
#  'Vesakkotie': 0.002914672339706987,
#  'Vihdintie': 0.00357933330419383,
#  'Viikin normaalikoulu': 0.0026014737831618947,
#  'Viikin tiedepuisto': 0.00293999425837326,
#  'Viiskulma': 0.003300651625973249,
#  'Vilhonvuorenkatu': 0.00342846440208617,
#  'Voikukantie': 0.001976046758169217,
#  'Von Daehnin katu': 0.002017645905416558,
#  'Westendinasema': 0.0029481965317772526,
#  'Westendintie': 0.0024543274113115673,
#  'Yhdyskunnankuja': 0.002443035565218975,
#  'Ympyrätalo': 0.0038899084212407203}

# %%
sorted_pagerank=sorted(pagerank.items(),key=itemgetter(1),reverse=True)
sorted_pagerank
# Out:
# [('Haukilahdenkatu', 0.00431965900734245),
#  ('Itämerentori', 0.00412750452519659),
#  ('Laajalahden aukio', 0.004003204459193389),
#  ('Kamppi (M)', 0.003964559022112063),
#  ('Töölönlahdenkatu', 0.003938348877990376),
#  ('Kaisaniemenpuisto', 0.003897151930804098),
#  ('Paciuksenkaari', 0.003895174227627984),
#  ('Ympyrätalo', 0.0038899084212407203),
#  ('Huopalahdentie', 0.0038823920721154153),
#  ('Rautatientori / länsi', 0.0038731303796092896),
#  ('Narinkka', 0.003860735355514737),
#  ('Munkkiniemen aukio', 0.003822221537375289),
#  ('Korjaamo', 0.00381675984666356),
#  ('Töölöntulli', 0.003814995756879654),
#  ('Baana', 0.0038017562656958424),
#  ('Tilkanvierto', 0.0038015449836469087),
#  ('Rautatientori / itä', 0.003794483668456338),
#  ('Sörnäinen (M)', 0.0037864038725811764),
#  ('Aalto-yliopisto (M), Korkeakouluaukio', 0.003769177733021174),
#  ('Diakoniapuisto', 0.003753881160334786),
#  ('Lehtisaarentie', 0.0037491357921800926),
#  ('Fleminginkatu', 0.003744783385330602),
#  ('Vanha kirkkopuisto', 0.0037406043530249854),
#  ('Messeniuksenkatu', 0.003730935886825378),
#  ('Saunalahdentie', 0.0037152364779942755),
#  ('Eteläinen Hesperiankatu', 0.0037140844551127815),
#  ('Marian sairaala', 0.0037023396510610417),
#  ('Kuusitie', 0.003688881808993938),
#  ('Tenholantie', 0.003673027981913896),
#  ('Esterinportti', 0.003671552216988659),
#  ('Lauttasaaren ostoskeskus', 0.00366995243957641),
#  ('Paciuksenkatu', 0.0036685687779151837),
#  ('Ooppera', 0.0036666541864604574),
#  ('Hietalahdentori', 0.0036614589512050525),
#  ('Rautatieläisenkatu', 0.0036483029910159078),
#  ('Ratapihantie', 0.0036449992013044222),
#  ('Nordenskiöldinaukio', 0.003640007326909361),
#  ('Meilahden sairaala', 0.003636258104342151),
#  ('Linnanmäki', 0.0036323531547844006),
#  ('Torpanranta', 0.003625920970692453),
#  ('Jätkäsaarenlaituri', 0.0036243433265188037),
#  ('Otaranta', 0.0036215794235259025),
#  ('Jämeräntaival', 0.0036198094405105307),
#  ('Länsisatamankatu', 0.0036102782972864725),
#  ('Hertanmäenkatu', 0.0036061164514923404),
#  ('Seurasaari', 0.0036057884927348676),
#  ('Kesäkatu', 0.003602473767484768),
#  ('Olympiastadion', 0.0036013338572494723),
#  ('Leppäsuonaukio', 0.003595868826553138),
#  ('Brahen kenttä', 0.0035908666836442405),
#  ('Apollonkatu', 0.0035836378237926784),
#  ('Eteläesplanadi', 0.003581296783929918),
#  ('Mäkelänkatu', 0.0035799332147618775),
#  ('Vihdintie', 0.00357933330419383),
#  ('Kiasma', 0.0035657210000324996),
#  ('Kalasatama (M)', 0.0035651201811866292),
#  ('Kanavaranta', 0.0035643559989106447),
#  ('Lastenlehto', 0.003562075625570916),
#  ('Hakaniemi (M)', 0.003554312167362268),
#  ('Venttiilikuja', 0.0035458154699896834),
#  ('Elimäenkatu', 0.003543897339753757),
#  ('Pernajantie', 0.0035402900642026954),
#  ('Töölöntori', 0.003534650744928585),
#  ('Unioninkatu', 0.003532393043426784),
#  ('Uimastadion', 0.003532077273247341),
#  ('Porthania', 0.0035238123668830785),
#  ('Gebhardinaukio', 0.00352145507863747),
#  ('Tilkantori', 0.0035142743940130157),
#  ('Stenbäckinkatu', 0.003511285380649128),
#  ('Haagan tori', 0.0035084660013171387),
#  ('Pasilan asema', 0.0035056239906237022),
#  ('Keilaniemi (M)', 0.0034969376686466505),
#  ('Luoteisväylä', 0.0034957479258567775),
#  ('Koskelantie', 0.0034946021180295734),
#  ('Arabian kauppakeskus', 0.0034932973596494723),
#  ('Jalavatie', 0.0034884451159723565),
#  ('Sepänkatu', 0.003483238621242362),
#  ('Keilaranta', 0.0034807016870505897),
#  ('Näkinsilta', 0.003474286798695986),
#  ('Mannerheimintie', 0.003471369745676589),
#  ('Kustaankatu', 0.0034699768312359556),
#  ('Teollisuuskatu', 0.0034590266297011597),
#  ('Varsapuistikko', 0.0034584917137027936),
#  ('Teljäntie', 0.00345666682270758),
#  ('Gyldenintie', 0.0034520815679557624),
#  ('Teurastamo', 0.003448400765722087),
#  ('Lauttasaarensilta', 0.0034396300350987338),
#  ('Kaivopuisto', 0.0034385564127807546),
#  ('Rajasaarentie', 0.003435461271278347),
#  ('Brahen puistikko', 0.003433560318759679),
#  ('Keilalahti', 0.0034332589884848263),
#  ('Ulvilantie', 0.0034320066667312635),
#  ('Jäähalli', 0.003430542843175286),
#  ('Vilhonvuorenkatu', 0.00342846440208617),
#  ('Töölönkatu', 0.0034264239950827628),
#  ('Arabiankatu', 0.003414043371464274),
#  ('Isoisänsilta', 0.003404907664636172),
#  ('Töölönlahden puisto', 0.003403495883552499),
#  ('Kalevankatu', 0.003402505956955787),
#  ('Kriikunakuja', 0.003392556579488789),
#  ('Toinen linja', 0.0033924651612768472),
#  ('Korppaanmäentie', 0.003389799955839922),
#  ('Lintulahdenkatu', 0.0033783858117051985),
#  ('Kiskontie', 0.003375153844683216),
#  ('Puistokaari', 0.0033680858082941263),
#  ('Opastinsilta', 0.003361100087302381),
#  ('Sammonpuistikko', 0.0033549933327897243),
#  ('Tunnelitie', 0.003345206102900903),
#  ('Hietaniemenkatu', 0.003341370598222792),
#  ('Liisanpuistikko', 0.0033365644689836303),
#  ('Laajalahden keskus', 0.0033351581902936024),
#  ('Verkatehtaanpuisto', 0.0033267012924188643),
#  ('Karhupuisto', 0.0033189114219887767),
#  ('Hollolantie', 0.003318744545890926),
#  ('Paavalinpuisto', 0.003314109347064626),
#  ('Haapaniemenkatu', 0.003311971731424127),
#  ('Velodrominrinne', 0.0033011444720768427),
#  ('Viiskulma', 0.003300651625973249),
#  ('Perämiehenkatu', 0.0032986992028421398),
#  ('Intiankatu', 0.0032980990532531485),
#  ('Muusantori', 0.0032959180255385193),
#  ('Albertinkatu', 0.0032922641091317605),
#  ('Kapteeninpuistikko', 0.00328842783940281),
#  ('Annankatu', 0.0032807234451251452),
#  ('Radiokatu', 0.0032776130797009875),
#  ('Heikkilänaukio', 0.003271228208682197),
#  ('Kauppakorkeakoulu', 0.003269252481056516),
#  ('Päijänteentie', 0.003268298790906858),
#  ('Maistraatintori', 0.003267854674953261),
#  ('Käpyläntie', 0.003265436709416852),
#  ('Vanha Viertotie', 0.003252299499533454),
#  ('Huopalahden asema', 0.0032435316055745215),
#  ('Arielinkatu', 0.00324348080149646),
#  ('Aalto-yliopisto (M), Tietotie', 0.003243304916659689),
#  ('Kuikkarinne', 0.003229453952256805),
#  ('Valimotie', 0.0032273226939009475),
#  ('Senaatintori', 0.003225312240133375),
#  ('Käpylän asema', 0.0032246271497456706),
#  ('Takomotie', 0.003209864051292789),
#  ('Ruskeasuon varikko', 0.0031952830994050863),
#  ('Tapionaukio', 0.003186980977370591),
#  ('Sateentie', 0.003176400002015234),
#  ('Heikkiläntie', 0.0031750539535178586),
#  ('Erottajan aukio', 0.003173197240504155),
#  ('Kansallismuseo', 0.003173123758516657),
#  ('Leppävaaranaukio', 0.0031644168565415067),
#  ('Pohjolanaukio', 0.003141370644082445),
#  ('Tyynenmerenkatu', 0.0031144997519330707),
#  ('Salmisaarenranta', 0.0031093778648836846),
#  ('Otsolahti', 0.003108120396519279),
#  ('Sähkömies', 0.0031014296593512287),
#  ('Hernesaarenranta', 0.0031011969011560544),
#  ('Ilmalan asema', 0.0030941561068474903),
#  ('Ritarikatu', 0.0030860170215482397),
#  ('Thalianaukio', 0.0030785862252098437),
#  ('Kulosaari (M)', 0.003065834641158331),
#  ('Eläinmuseo', 0.00306435622868397),
#  ('Eerikinkatu', 0.0030642898185722217),
#  ('Merihaka', 0.003056729064737123),
#  ('Tekniikantie', 0.003052002247328695),
#  ('Itälahdenkatu', 0.0030484596037634168),
#  ('Cygnaeuksenkatu', 0.0030392678137698094),
#  ('Betonimies', 0.0030245205232787486),
#  ('Katariina Saksilaisen katu', 0.0030204657208476524),
#  ('Länsisatamankuja', 0.0030156828477101547),
#  ('Hanasaari', 0.0029985744427163466),
#  ('Pajamäki', 0.0029940571979486966),
#  ('Gallen-Kallelan tie', 0.0029895638566964323),
#  ('Mäntyviita', 0.0029803159038891587),
#  ('Juhana Herttuan tie', 0.002976096551594403),
#  ('Leppävaarankäytävä', 0.00296275057925434),
#  ('Ratsutori', 0.002961235259219523),
#  ('Sofianlehdonkatu', 0.0029504239173741517),
#  ('Pohjolankatu', 0.0029493568093023705),
#  ('Westendinasema', 0.0029481965317772526),
#  ('Näyttelijäntie', 0.0029469046428598385),
#  ('Viikin tiedepuisto', 0.00293999425837326),
#  ('Designmuseo', 0.0029370874374425532),
#  ('A.I. Virtasen aukio', 0.0029364306240015673),
#  ('Oulunkylän asema', 0.002930978743897136),
#  ('Huovitie', 0.00292203195804388),
#  ('Urheilupuisto (M)', 0.0029183737403161696),
#  ('Lepolantie', 0.002917273904472884),
#  ('Vesakkotie', 0.002914672339706987),
#  ('Herttoniemi (M)', 0.0029074868408380597),
#  ('Pohjois-Haagan asema', 0.0029032216997081253),
#  ('Vallilan\xa0varikko', 0.002895646664355951),
#  ('Revontulentie', 0.002895244033422838),
#  ('Relanderinaukio', 0.0028921130082546495),
#  ('Mustikkamaa', 0.0028912300159840165),
#  ('Kasarmitori', 0.002890639763935359),
#  ('Länsituuli', 0.0028878181044359945),
#  ('Laivasillankatu', 0.0028840402281752214),
#  ('Petter Wetterin tie', 0.0028815470542246317),
#  ('Jännetie', 0.0028799039860847855),
#  ('Majurinkulma', 0.002874332760284057),
#  ('Piispansilta', 0.0028728314158514034),
#  ('Kulttuuriaukio', 0.002872757954590653),
#  ('Kirjurinkuja', 0.0028625103008741333),
#  ('Vanha Kauppahalli', 0.0028561330484065625),
#  ('Säteri', 0.0028502925587314785),
#  ('Pitäjänmäen asema', 0.00284986772580795),
#  ('Valimon asema', 0.0028413142065689123),
#  ('Pohjankulma', 0.0028363646825611826),
#  ('Maunula', 0.002825411901206651),
#  ('Kalevalantie', 0.0028244931963117064),
#  ('Ehrenströmintie', 0.002822144018886397),
#  ('Kaapelitehdas', 0.002821946111923915),
#  ('Niittykumpu (M)', 0.002802390366203418),
#  ('Metsänneidonpolku', 0.00280231426885365),
#  ('Kylävoudintie', 0.002793277552915321),
#  ('Melkonkuja', 0.002788531187567336),
#  ('Muotoilijankatu', 0.00277117937326244),
#  ('Hämeenlinnanväylä', 0.0027648856082187413),
#  ('Niittymaa', 0.002759721954224843),
#  ('Marttila', 0.0027338550923925167),
#  ('Koskelan varikko', 0.002711929919820962),
#  ('Hakalehto', 0.0026777780508249055),
#  ('Herttoniemenranta', 0.0026642099854850424),
#  ('Innopoli', 0.0026641180141366654),
#  ('Otto Brandtin tie', 0.002662004180612847),
#  ('Ahertajantie', 0.0026582850218117085),
#  ('Mankkaanaukio', 0.0026483011905366538),
#  ('Hernepellontie', 0.002646245866964501),
#  ('Mäkkylän asema', 0.0026434905413400345),
#  ('Mastokatu', 0.0026399631057273435),
#  ('Merisotilaantori', 0.0026369504865065324),
#  ('Louhentori', 0.002635692325800544),
#  ('Tietäjä', 0.0026299991763421757),
#  ('Maarinranta', 0.0026272789998376743),
#  ('Läkkitori', 0.0026255715534944653),
#  ('Rummunlyöjänkatu', 0.002606227783154052),
#  ('Viikin normaalikoulu', 0.0026014737831618947),
#  ('Siltavoudintie', 0.002592979228796066),
#  ('Ida Aalbergin tie', 0.0025862647996465708),
#  ('Mankkaanlaaksontie', 0.0025835924802909893),
#  ('Laivalahden puistotie', 0.0025727183272200617),
#  ('Tupasaarentie', 0.00255971112447564),
#  ('Mäkitorpantie', 0.002547590766236892),
#  ('Suomenlahdentie', 0.002524810451660697),
#  ('Kustaankartano', 0.0025219866203280033),
#  ('Eränkävijäntori', 0.002508345809262693),
#  ('Herttoniemen kirkko', 0.0025082494859329546),
#  ('Kalkkipellonmäki', 0.0025035575975228866),
#  ('Lumivaarantie', 0.0025024806868259417),
#  ('Länsiterminaali', 0.002479239136308629),
#  ('Oravannahkatori', 0.002464916492616549),
#  ('Westendintie', 0.0024543274113115673),
#  ('Abraham Wetterin tie', 0.002450546070724548),
#  ('Yhdyskunnankuja', 0.002443035565218975),
#  ('Pihlajamäki', 0.0024428965123461867),
#  ('Asentajanpuisto', 0.00243931377094286),
#  ('Tapiolan urheilupuisto', 0.002427205646190353),
#  ('Korkeasaari', 0.0024227045291895363),
#  ('Aulangontie', 0.0024214315509069498),
#  ('Mellstenintie', 0.002420314344770089),
#  ('Säterinniitty', 0.0024060249093547687),
#  ('Siilitie (M)', 0.002383900000419379),
#  ('Agronominkatu', 0.002383486069748388),
#  ('Golfpolku', 0.0023788613295979417),
#  ('Kirkkoherrantie', 0.00237846320310361),
#  ('Linnakepolku', 0.002364764225968234),
#  ('Etuniementie', 0.0023339916923363034),
#  ('Agnetankuja', 0.0023305479274433405),
#  ('Käskynhaltijantie', 0.0023302527946090852),
#  ('Itäkeskus (M)', 0.002319963847095612),
#  ('Tuulimäki', 0.0023080752572243804),
#  ('Upseerinkatu', 0.0022772657654097335),
#  ('Haukilahdenaukio', 0.0022684596293787514),
#  ('Säterinrinne', 0.002260167925050481),
#  ('Olarinluoma', 0.0022554395050624226),
#  ('Porolahden koulu', 0.0022516844736937733),
#  ('Painiitty', 0.0022305827083263746),
#  ('Siilitie 9', 0.0022072894931197797),
#  ('Toppelundinportti', 0.0022044664701989665),
#  ('Muurarinkuja', 0.00218267626151864),
#  ('Hagalundinpuisto', 0.0021820980494181887),
#  ('Koivu-Mankkaa', 0.002172658339175239),
#  ('Kuunkatu', 0.002170221887841359),
#  ('Haukilahdenranta', 0.0021698606846212907),
#  ('Matinkartanontie', 0.0021649699372825798),
#  ('Margareetankuja', 0.0021415371917046905),
#  ('Laajasalon ostoskeskus', 0.002128901730676243),
#  ('Postipuun koulu', 0.0021186252031629633),
#  ('Auringonkatu', 0.0021155491561996452),
#  ('Linnuntie', 0.0021115557619858787),
#  ('Nokkala', 0.002097624298149751),
#  ('Tammisalon aukio', 0.002094564085407738),
#  ('Komentajankatu', 0.0020863590875429406),
#  ('Isosaarentie', 0.0020843602946578645),
#  ('Leppävaaran urheilupuisto', 0.0020777876309238303),
#  ('Roihupelto', 0.0020673953295458555),
#  ('Ruomelantie', 0.0020651773940605768),
#  ('Nelikkotie', 0.0020632721334453816),
#  ('Piispankallio', 0.002049900199410091),
#  ('Vallipolku', 0.002048773183811409),
#  ('Myllypuro (M)', 0.002043687471045781),
#  ('Piispanportti', 0.0020379623103409105),
#  ('Lukutori', 0.002024298879768358),
#  ('Von Daehnin katu', 0.002017645905416558),
#  ('Tontunmäentie', 0.0020011748445802383),
#  ('Tulisuontie', 0.00199609686598154),
#  ('Voikukantie', 0.001976046758169217),
#  ('Peukaloisentie', 0.001972928114609401),
#  ('Friisilänaukio', 0.0019578102992072405),
#  ('Leppävaaran uimahalli', 0.0019573508701847984),
#  ('Suurpellonaukio', 0.0019517221769447906),
#  ('Reiherintie', 0.001943506581897503),
#  ('Hauenkalliontie', 0.0019403233969387582),
#  ('Komeetankatu', 0.0019387108621665085),
#  ('Elfvik', 0.0019326221061778499),
#  ('Toppelundintie', 0.0019209167209296705),
#  ('Lystimäki', 0.0019173897985714325),
#  ('Kutsuntatie', 0.001894830785159501),
#  ('Vallikatu', 0.001881697261020505),
#  ('Humalniementie', 0.0018668900495875142),
#  ('Siilitie 13', 0.0018627272928772134),
#  ('Matinlahdenranta', 0.0018593298854631647),
#  ('Itäportti', 0.001846357830693902),
#  ('Hauenkallio', 0.0018175001482259876),
#  ('Matinkyläntie', 0.0018127755743282063),
#  ('Gransinmäki', 0.0017957679798319471),
#  ('Puotila (M)', 0.001769860054713542),
#  ('Mamsellimyllynkatu', 0.0017650114035462053),
#  ('Marjaniementie', 0.0017579622672124814),
#  ('Tiistinkallio', 0.0017556694769523843),
#  ('Ruutikatu', 0.001754335393583602),
#  ('Gunillantie', 0.001747527837798963),
#  ('Nuottaniementie', 0.0017339167137691183),
#  ('Orionintie', 0.0017326050271412638),
#  ('Puotinharju', 0.0017261045211837583),
#  ('Prinsessantie', 0.0017236967453728223),
#  ('Lystimäensilta', 0.00170625938182657),
#  ('Puotilan ostoskeskus', 0.0016978500711640964),
#  ('Orpaanporras', 0.0016882881625633422),
#  ('Karhulantie', 0.0016618025189943314),
#  ('Avaruuskatu', 0.0016601012211478812),
#  ('Sepetlahdentie', 0.00164444355170336),
#  ('Puotilantie', 0.0016236934488247363),
#  ('Alakiventie', 0.0016143081086448057),
#  ('Tiistiläntie', 0.0015876074949066862),
#  ('Outotec', 0.0015278039813173161),
#  ('Puotinkylän kartano', 0.0014945719047851985),
#  ('Marjaniemi', 0.0014587031130526666),
#  ('Haakoninlahdenkatu', 0.001353251327052279),
#  ('Itäkeskus Metrovarikko', 0.0013186521811749436),
#  ('Derby Business Park', 0.0013134723836778182)]

# %%
for t in sorted_pagerank[:5]:
        print(t)
# Out:
# ('Haukilahdenkatu', 0.00431965900734245)
# ('Itämerentori', 0.00412750452519659)
# ('Laajalahden aukio', 0.004003204459193389)
# ('Kamppi (M)', 0.003964559022112063)
# ('Töölönlahdenkatu', 0.003938348877990376)

# %%
t8=sorted([d for n,d in sorted_pagerank],reverse=True)
degreeCount = collections.Counter(t8)
deg, cnt = zip(*degreeCount.items())

# %%
fig,ax=plt.subplots(figsize=(15,7))

plt.scatter(deg,cnt,color='blue')

# %% [markdown]
# Conclusion: Haukilahdenkatu has the highest pagerank centrality followed by Itamerentori and Laajalahden

# %%
cc=nx.average_clustering(G)
cc
# Out:
# 0.7796808968676939

# %%
gc=G.subgraph(max(nx.connected_components(G)))
lcc=nx.clustering(gc)
cmap=plt.get_cmap('autumn')
norm=plt.Normalize(0,max(lcc.values()))
node_colors=[cmap(norm(lcc[node])) for node in gc.nodes]
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 4))
nx.draw_spring(gc, node_color=node_colors, with_labels=True, ax=ax1)
fig.colorbar(cm.ScalarMappable(cmap=cmap, norm=norm), label='Clustering', shrink=0.95, ax=ax1)

ax2.hist(lcc.values(), bins=10)
ax2.set_xlabel('Clustering')
ax2.set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
H=G.copy()

# %%
nx.info(H)
# Out:
# 'Graph with 347 nodes and 36462 edges'

# %%
def edge_to_remove(g):
	
	d1 = nx.edge_betweenness_centrality(g)
	list_of_tuples = list(d1.items())
	
	sorted(list_of_tuples, key = lambda x:x[1], reverse = True)
	
	# Will return in the form (a,b)
	return list_of_tuples[0][0]

def girvan(g):
	a = nx.connected_components(g)
	lena = len(list(a))
	print (' The number of connected components are ', lena)
	while (lena == 1):

		# We need (a,b) instead of ((a,b))
		u, v = edge_to_remove(g)
		g.remove_edge(u, v)
		
		a = nx.connected_components(g)
		lena=len(list(a))
		print (' The number of connected components are ', lena)
	
	return a

# Driver Code
H=G.copy()
a = girvan(H)


for i in a:
	print (i.nodes())
	print ('.............')
# Out:
#  The number of connected components are  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-a87ea2a6b49d> in <module>()
#      30 # Driver Code
#      31 H=G.copy()
# ---> 32 a = girvan(H)
#      33
#      34
#
# <ipython-input-42-a87ea2a6b49d> in girvan(g)
#      19
#      20                 # We need (a,b) instead of ((a,b))
# ---> 21                 u, v = edge_to_remove(g)
#      22                 g.remove_edge(u, v)
#      23
#
# <ipython-input-42-a87ea2a6b49d> in edge_to_remove(g)
#       4 def edge_to_remove(g):
#       5
# ----> 6         d1 = nx.edge_betweenness_centrality(g)
#       7         list_of_tuples = list(d1.items())
#       8
#
# /usr/local/lib/python3.7/dist-packages/networkx/utils/decorators.py in func(_argmap__wrapper, *args, **kwargs)
#     793
#     794             def func(*args, __wrapper=None, **kwargs):
# --> 795                 return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#     796
#     797         # standard function-wrapping stuff
#
# /usr/local/lib/python3.7/dist-packages/networkx/utils/decorators.py in argmap_edge_betweenness_centrality_30(G, k, normalized, weight, seed)
#       2 from os.path import splitext
#       3 from contextlib import contextmanager
# ----> 4 from pathlib import Path
#       5 import warnings
#       6
#
# /usr/local/lib/python3.7/dist-packages/networkx/algorithms/centrality/betweenness.py in edge_betweenness_centrality(G, k, normalized, weight, seed)
#     226         # single source shortest paths
#     227         if weight is None:  # use BFS
# --> 228             S, P, sigma, _ = _single_source_shortest_path_basic(G, s)
#     229         else:  # use Dijkstra's algorithm
#     230             S, P, sigma, _ = _single_source_dijkstra_path_basic(G, s, weight)
#
# /usr/local/lib/python3.7/dist-packages/networkx/algorithms/centrality/betweenness.py in _single_source_shortest_path_basic(G, s)
#     272             if D[w] == Dv + 1:  # this is a shortest path, count paths
#     273                 sigma[w] += sigmav
# --> 274                 P[w].append(v)  # predecessors
#     275     return S, P, sigma, D
#     276
#
# KeyboardInterrupt:

# %%
T=G.copy()

# %%
for i in a:
    print (i.nodes())
    print ('.............')

# %%
a.nodes()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-83-1c328c178ec2> in <module>()
# ----> 1 a.nodes()
#
# AttributeError: 'generator' object has no attribute 'nodes'

# %%
from networkx.algorithms.community import k_clique_communities
K5=nx.convert_node_labels_to_integers(T, first_label=2)
T.add_edges_from(K5.edges())
c = list(k_clique_communities(T, 2))
sorted(list(c[0]))

# %%
import community

# %%
from networkx.algorithms import community

# %%
import networkx as nx
import community as community_louvain
from operator import itemgetter

# %%
comms = community_louvain.best_partition(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-856be4713eda> in <module>()
# ----> 1 comms = community_louvain.best_partition(G)
#
# AttributeError: module 'community' has no attribute 'best_partition'

# %%
# !pip install community
# !pip install python-louvain
# Out:
# Collecting community
#   Downloading community-1.0.0b1.tar.gz (2.2 kB)
# Requirement already satisfied: Flask in /usr/local/lib/python3.7/dist-packages (from community) (1.1.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from community) (2.23.0)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.7/dist-packages (from Flask->community) (2.11.3)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.7/dist-packages (from Flask->community) (1.1.0)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.7/dist-packages (from Flask->community) (7.1.2)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.7/dist-packages (from Flask->community) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.7/dist-packages (from Jinja2<3.0,>=2.10.1->Flask->community) (2.0.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->community) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->community) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->community) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->community) (2021.10.8)
# Building wheels for collected packages: community
#   Building wheel for community (setup.py) ... done
#   Created wheel for community: filename=community-1.0.0b1-py3-none-any.whl size=2154 sha256=4fef8242693f0d65e4e2cf59f198e105990725a9c86fd9f8fd7c78d17f5f5460
#   Stored in directory: /root/.cache/pip/wheels/d9/cf/a6/01e9b603fca646a52b27e42d5c5613cb167c5258109d59ea23
# Successfully built community
# Installing collected packages: community
# Successfully installed community-1.0.0b1
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.7/dist-packages (0.16)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from python-louvain) (1.21.6)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from python-louvain) (2.6.3)

# %%
# !pip uninstall community
# !pip install python-louvain
# Out:
# Found existing installation: community 1.0.0b1
# Uninstalling community-1.0.0b1:
#   Would remove:
#     /usr/local/lib/python3.7/dist-packages/community-1.0.0b1.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/community/*
#   Would not remove (might be manually added):
#     /usr/local/lib/python3.7/dist-packages/community/community_louvain.py
#     /usr/local/lib/python3.7/dist-packages/community/community_status.py
# Proceed (y/n)? y
#   Successfully uninstalled community-1.0.0b1
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.7/dist-packages (0.16)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from python-louvain) (2.6.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from python-louvain) (1.21.6)

# %%
import community.community_louvain

# %%
def communityCombo(G):
    """
    """
    # Figure
    fig, ax = plt.subplots(figsize=(20,11))

    # Partition
    partition, modularity = pycombo.execute(G, return_modularity=True, modularity_resolution= 1,  weight="duration", max_communities=5, random_seed=1)

    # Partition colormap
    cmap = cm.get_cmap('tab20b', max(partition.values()) + 1)

    # Draw Nodes & Edges
    nx.draw_networkx_nodes(G, G.nodes.data('pos'), partition.keys(), node_size=40, cmap=cmap, node_color=list(partition.values()))
    nx.draw_networkx_edges(G, G.nodes.data('pos'), alpha=0.015)

    # Labeling Axes
    ax.set_title('Helsinki City Bike Network Communities (Combo method)', fontdict={"fontsize":20}, pad = 15)
    ax.axis('off')

    # Watermark
    

    plt.show()
communityCombo(G)

# %%
def communityLouvain(G):
    """
    This function applies the Louvain method for community detection on the City bike network.
    """

    # Figure
    fig, ax = plt.subplots(figsize=(20,11))

    # Compute Louvain method
    partition = community_louvain.best_partition(G, resolution=0.95, random_state=1)

    # Partition colormap
    cmap = cm.get_cmap('tab20b', max(partition.values()) + 1)

    # Draw Nodes & Edges
    nx.draw_networkx_nodes(G, G.nodes.data('pos'), partition.keys(), node_size=40, cmap=cmap, node_color=list(partition.values()))
    nx.draw_networkx_edges(G, G.nodes.data('pos'), alpha=0.015)

    # Labeling Axes
    ax.set_title('Helsinki City Bike Network Communities (Louvain method)', fontdict={"fontsize":20}, pad = 15)
    ax.axis('off')

    # Watermark
    ax.text(0.99, 0.01, '© Github/Geometrein',
            verticalalignment='bottom',
            horizontalalignment='right',
            transform=ax.transAxes,
            color='grey',
            fontsize=15,
            alpha = 0.9)

    plt.show()
    
communityLouvain(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-74-2a097379b5e4> in <module>()
#      32     plt.show()
#      33
# ---> 34 communityLouvain(G)
#
# <ipython-input-74-2a097379b5e4> in communityLouvain(G)
#       8
#       9     # Compute Louvain method
# ---> 10     partition = community_louvain.best_partition(G, resolution=0.95, random_state=1)
#      11
#      12     # Partition colormap
#
# AttributeError: module 'community' has no attribute 'best_partition'

# %%
def communityFluid(G):
    """
    This function applies the Fluid Communities method for community detection on the City bike network.
    """

    # Figure
    fig, ax = plt.subplots(figsize=(20,11))

    # Compute Fluid method
    communities = nx.algorithms.community.asyn_fluid.asyn_fluidc(G, k=5, max_iter=10000, seed=1)
    
    # Assigning each node to its cluster
    partition = {}
    for idx, val in enumerate(communities):
        for k in val:
            partition[k] = idx
    cmap = cm.get_cmap('tab20b', max(partition.values()) + 1)
    nx.draw_networkx_nodes(G, G.nodes.data('pos'), partition.keys(), node_size=40, cmap=cmap, node_color=list(partition.values()))
    nx.draw_networkx_edges(G, G.nodes.data('pos'), alpha=0.015)

    # Labeling Axes
    ax.set_title('Helsinki City Bike Network Communities (Fluid Communities method)', fontdict={"fontsize":20}, pad = 15)
    ax.axis('off')
    

    plt.show()
    
communityFluid(G)

# %%
from networkx import asyn_lpa, Graph
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-66-067fbcc1f4d1> in <module>()
# ----> 1 from networkx import asyn_lpa, Graph
#
# ImportError: cannot import name 'asyn_lpa' from 'networkx' (/usr/local/lib/python3.7/dist-packages/networkx/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
def communityFluid(G):
    """
    This function applies the Fluid Communities method for community detection on the City bike network.
    """

    # Figure
    fig, ax = plt.subplots(figsize=(20,11))

    # Compute Fluid method
    communities = nx.asyn_lpa_communities(G, weight=None, seed=None)
    
    # Assigning each node to its cluster
    partition = {}
    for idx, val in enumerate(communities):
        for k in val:
            partition[k] = idx
    cmap = cm.get_cmap('tab20b', max(partition.values()) + 1)
    nx.draw_networkx_nodes(G, G.nodes.data('pos'), partition.keys(), node_size=40, cmap=cmap, node_color=list(partition.values()))
    nx.draw_networkx_edges(G, G.nodes.data('pos'), alpha=0.015)

    # Labeling Axes
    ax.set_title('Helsinki City Bike Network Communities (Fluid Communities method)', fontdict={"fontsize":20}, pad = 15)
    ax.axis('off')
    ax.text(0.99, 0.01, '© Github/Geometrein',
            verticalalignment='bottom',
            horizontalalignment='right',
            transform=ax.transAxes,
            color='grey',
            fontsize=15,
            alpha = 0.9)

    plt.show()
    
communityFluid(G)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-62-d7779fcc807c> in <module>()
#      32     plt.show()
#      33
# ---> 34 communityFluid(G)
#
# <ipython-input-62-d7779fcc807c> in communityFluid(G)
#       8
#       9     # Compute Fluid method
# ---> 10     communities = nx.asyn_lpa_communities(G, weight=None, seed=None)
#      11
#      12     # Assigning each node to its cluster
#
# /usr/local/lib/python3.7/dist-packages/networkx/__init__.py in __getattr__(name)
#      49             "This message will be removed in NetworkX 3.0."
#      50         )
# ---> 51     raise AttributeError(f"module {__name__} has no attribute {name}")
#      52
#      53
#
# AttributeError: module networkx has no attribute asyn_lpa_communities

# %%
v=G.community_infomap()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-0b92b27e3e16> in <module>()
# ----> 1 v=G.community_infomap()
#
# AttributeError: 'Graph' object has no attribute 'community_infomap'
